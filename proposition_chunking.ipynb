# %% [markdown]
# # Propositions Chunking

# %% [markdown]
# ### Overview
#
# This code implements the proposition chunking method. The system break downs the input text into propositions that are atomic, factual, self-contained, and concise in nature, encodes the propositions into a vectorstore, which can be later used for retrieval
#
# ### Key Components
#
# 1. **Document Chunking:** Splitting a document into manageable pieces for analysis.
# 2. **Proposition Generation:** Using LLMs to break down document chunks into factual, self-contained propositions.
# 3. **Proposition Quality Check:** Evaluating generated propositions based on accuracy, clarity, completeness, and conciseness.
# 4. **Embedding and Vector Store:** Embedding both propositions and larger chunks of the document into a vector store for efficient retrieval.
# 5. **Retrieval and Comparison:** Testing the retrieval system with different query sizes and comparing results from the proposition-based model with the larger chunk-based model.
#
# <img src="../images/proposition_chunking.svg" alt="Reliable-RAG" width="600">
#
# ### Motivation
#
# The motivation behind the propositions chunking method is to build a system that breaks down a text document into concise, factual propositions for more granular and precise information retrieval. Using propositions allows for finer control and better handling of specific queries, particularly for extracting knowledge from detailed or complex texts. The comparison between using smaller proposition chunks and larger document chunks aims to evaluate the effectiveness of granular information retrieval.
#
# ### Method Details
#
# 1. **Loading Environment Variables:** The code begins by loading environment variables (e.g., API keys for the LLM service) to ensure that the system can access the necessary resources.
#
# 2. **Document Chunking:**
#    - The input document is split into smaller pieces (chunks) using `RecursiveCharacterTextSplitter`. This ensures that each chunk is of manageable size for the LLM to process.
#
# 3. **Proposition Generation:**
#    - Propositions are generated from each chunk using an LLM (in this case, "llama-3.1-70b-versatile"). The output is structured as a list of factual, self-contained statements that can be understood without additional context.
#
# 4. **Quality Check:**
#    - A second LLM evaluates the quality of the propositions by scoring them on accuracy, clarity, completeness, and conciseness. Propositions that meet the required thresholds in all categories are retained.
#
# 5. **Embedding Propositions:**
#    - Propositions that pass the quality check are embedded into a vector store using the `OllamaEmbeddings` model. This allows for similarity-based retrieval of propositions when queries are made.
#
# 6. **Retrieval and Comparison:**
#    - Two retrieval systems are built: one using the proposition-based chunks and another using larger document chunks. Both are tested with several queries to compare their performance and the precision of the returned results.
#
# ### Benefits
#
# - **Granularity:** By breaking the document into small factual propositions, the system allows for highly specific retrieval, making it easier to extract precise answers from large or complex documents.
# - **Quality Assurance:** The use of a quality-checking LLM ensures that the generated propositions meet specific standards, improving the reliability of the retrieved information.
# - **Flexibility in Retrieval:** The comparison between proposition-based and larger chunk-based retrieval allows for evaluating the trade-offs between granularity and broader context in search results.
#
# ### Implementation
#
# 1. **Proposition Generation:** The LLM is used in conjunction with a custom prompt to generate factual statements from the document chunks.
# 2. **Quality Checking:** The generated propositions are passed through a grading system that evaluates accuracy, clarity, completeness, and conciseness.
# 3. **Vector Store Integration:** Propositions are stored in a FAISS vector store after being embedded using a pre-trained embedding model, allowing for efficient similarity-based search and retrieval.
# 4. **Query Testing:** Multiple test queries are made to the vector stores (proposition-based and larger chunks) to compare the retrieval performance.
#
# ### Summary
#
# This code presents a robust method for breaking down a document into self-contained propositions using LLMs. The system performs a quality check on each proposition, embeds them in a vector store, and retrieves the most relevant information based on user queries. The ability to compare granular propositions against larger document chunks provides insight into which method yields more accurate or useful results for different types of queries. The approach emphasizes the importance of high-quality proposition generation and retrieval for precise information extraction from complex documents.

# %%
### LLMs
import os
from dotenv import load_dotenv

# Load environment variables from '.env' file
load_dotenv()

os.environ['GROQ_API_KEY'] = os.getenv('GROQ_API_KEY') # For LLM

# %% [markdown]
# ### Test Document

# %%
sample_content = """Paul Graham's essay "Founder Mode," published in September 2024, challenges conventional wisdom about scaling startups, arguing that founders should maintain their unique management style rather than adopting traditional corporate practices as their companies grow.
Conventional Wisdom vs. Founder Mode
The essay argues that the traditional advice given to growing companies—hiring good people and giving them autonomy—often fails when applied to startups.
This approach, suitable for established companies, can be detrimental to startups where the founder's vision and direct involvement are crucial. "Founder Mode" is presented as an emerging paradigm that is not yet fully understood or documented, contrasting with the conventional "manager mode" often advised by business schools and professional managers.
Unique Founder Abilities
Founders possess unique insights and abilities that professional managers do not, primarily because they have a deep understanding of their company's vision and culture.
Graham suggests that founders should leverage these strengths rather than conform to traditional managerial practices. "Founder Mode" is an emerging paradigm that is not yet fully understood or documented, with Graham hoping that over time, it will become as well-understood as the traditional manager mode, allowing founders to maintain their unique approach even as their companies scale.
Challenges of Scaling Startups
As startups grow, there is a common belief that they must transition to a more structured managerial approach. However, many founders have found this transition problematic, as it often leads to a loss of the innovative and agile spirit that drove the startup's initial success.
Brian Chesky, co-founder of Airbnb, shared his experience of being advised to run the company in a traditional managerial style, which led to poor outcomes. He eventually found success by adopting a different approach, influenced by how Steve Jobs managed Apple.
Steve Jobs' Management Style
Steve Jobs' management approach at Apple served as inspiration for Brian Chesky's "Founder Mode" at Airbnb. One notable practice was Jobs' annual retreat for the 100 most important people at Apple, regardless of their position on the organizational chart
. This unconventional method allowed Jobs to maintain a startup-like environment even as Apple grew, fostering innovation and direct communication across hierarchical levels. Such practices emphasize the importance of founders staying deeply involved in their companies' operations, challenging the traditional notion of delegating responsibilities to professional managers as companies scale.
"""

# %% [markdown]
# ### Chunking

# %%
### Build Index
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_core.documents import Document
from langchain_community.vectorstores import FAISS
from langchain_community.embeddings import OllamaEmbeddings
from llama_index.core import SimpleDirectoryReader, VectorStoreIndex


# Set embeddings
embedding_model = OllamaEmbeddings(model='nomic-embed-text:v1.5', show_progress=True)

# docs
#docs_list = [Document(page_content=sample_content, metadata={"Title": "Paul Graham's Founder Mode Essay", "Source": "https://www.perplexity.ai/page/paul-graham-s-founder-mode-ess-t9TCyvkqRiyMQJWsHr0fnQ"})]
# File path for the input document
FILE_PATH = "data/2024_2_AMD.txt"


path = "data/"
node_parser = SimpleDirectoryReader(input_dir=path, required_exts=['.txt'])
documents = node_parser.load_data()

# %%
docs_list = documents[20]
docs_list
# Out:
# Document(id_='aaf89235-8282-4a8c-ae81-8e07f716a178', embedding=None, metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 54058, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text="Operator: Greetings, and welcome to the Microsoft Fiscal Year 2024 First Quarter Earnings Conference Call. At this time, all participants are in a listen-only mode. A question-and-answer session will follow the formal presentation. [Operator Instructions] As a reminder, this conference is being recorded. I would now like to turn the call over to your host, Brett Iversen, Vice President of Investor Relations. Mr. Iversen, please go ahead.\nBrett Iversen: Good afternoon, and thank you for joining us today. On the call with me are Satya Nadella, Chairman and Chief Executive Officer; Amy Hood, Chief Financial Officer; Alice Jolla, Chief Accounting Officer; and Keith Dolliver, Corporate Secretary and Deputy General Counsel. On the Microsoft Investor Relations website, you can find our earnings press release and financial summary slide deck, which is intended to supplement our prepared remarks during today's call, and provides the reconciliation of differences between GAAP and non-GAAP financial measures. More detailed outlook slides will be available on the Microsoft Investor Relations website when we provide outlook commentary on today's call. Microsoft, completed the acquisition of Activision Blizzard, on October 13, 2023. We will share more on the expected impact of the Activision acquisition during the outlook commentary portion of today's call. On this call we will discuss certain non-GAAP items. The non-GAAP financial measures provided should not be considered as a substitute for or superior to the measures of financial performance prepared in accordance with GAAP. They are included as additional clarifying items to aid investors in further understanding the company's first-quarter performance, in addition to the impact these items and events have on the financial results. All growth comparisons we make on the call today, relate to the corresponding period of last year unless otherwise noted. We'll also provide growth rates in constant currency when available as a framework for assessing how our underlying businesses performed, excluding the effect of foreign currency rate fluctuations. Where growth rates are the same in constant currency, we will refer to the growth rate only. We will post our prepared remarks to our website immediately following the call until the complete transcript is available. Today's call is being webcast live and recorded. If you ask a question, it will be included in our live transmission in the transcript and in any future use of the recording. You can replay the call and view the transcript on the Microsoft Investor Relations website. During this call, we'll be making forward-looking statements, which are predictions, projections or other statements about future events. These statements are based on current expectations and assumptions that are subject to risks and uncertainties. Actual results could materially differ because of factors discussed in today's earnings press release, in the comments made during this conference call, and in the Risk Factors section of our Form 10-K, Form 10-Q, and other reports and filings with the Securities and Exchange Commission. We do not undertake any duty to update any forward-looking statement. And with that, I'll turn the call over to Satya.\nSatya Nadella: Thank you, Brett. We are off to a strong start to the fiscal year, driven by the continued strength in Microsoft  ...

# %%
def doc_split(documents):
    docs_list = [Document(page_content=documents.text, metadata=documents.metadata)]
    
    text_splitter = RecursiveCharacterTextSplitter.from_tiktoken_encoder(
        chunk_size=500, chunk_overlap=50)

    doc_splits = text_splitter.split_documents(docs_list)
    
    return doc_splits

# %%
doc_splits = doc_split(docs_list)

# %%
for i, doc in enumerate(doc_splits):
    doc.metadata['chunk_id'] = i+1 ### adding chunk id

# %%
len(doc_splits)
# Out:
# 30

# %% [markdown]
# ### Generate Propositions

# %%
from typing import List
from langchain_core.prompts import ChatPromptTemplate, FewShotChatMessagePromptTemplate
from langchain_core.pydantic_v1 import BaseModel, Field
from langchain_groq import ChatGroq

# Data model
class GeneratePropositions(BaseModel):
    """List of all the propositions in a given document"""

    propositions: List[str] = Field(
        description="List of propositions (factual, self-contained, and concise information)"
    )


# LLM with function call
llm = ChatGroq(model="llama-3.1-70b-versatile", temperature=0)
llm = ChatGroq(model='gemma2-9b-it')
structured_llm= llm.with_structured_output(GeneratePropositions)

# Few shot prompting --- We can add more examples to make it good
proposition_examples = [
    {"document": 
        "In 1969, Neil Armstrong became the first person to walk on the Moon during the Apollo 11 mission.", 
     "propositions": 
        "['Neil Armstrong was an astronaut.', 'Neil Armstrong walked on the Moon in 1969.', 'Neil Armstrong was the first person to walk on the Moon.', 'Neil Armstrong walked on the Moon during the Apollo 11 mission.', 'The Apollo 11 mission occurred in 1969.']"
    },
]

example_proposition_prompt = ChatPromptTemplate.from_messages(
    [
        ("human", "{document}"),
        ("ai", "{propositions}"),
    ]
)

few_shot_prompt = FewShotChatMessagePromptTemplate(
    example_prompt = example_proposition_prompt,
    examples = proposition_examples,
)

# Prompt
system = """Please break down the following text into simple, self-contained propositions. Ensure that each proposition meets the following criteria:

    1. Express a Single Fact: Each proposition should state one specific fact or claim.
    2. Be Understandable Without Context: The proposition should be self-contained, meaning it can be understood without needing additional context.
    3. Use Full Names, Not Pronouns: Avoid pronouns or ambiguous references; use full entity names.
    4. Include Relevant Dates/Qualifiers: If applicable, include necessary dates, times, and qualifiers to make the fact precise.
    5. Contain One Subject-Predicate Relationship: Focus on a single subject and its corresponding action or attribute, without conjunctions or multiple clauses."""
prompt = ChatPromptTemplate.from_messages(
    [
        ("system", system),
        few_shot_prompt,
        ("human", "{document}"),
    ]
)

proposition_generator = prompt | structured_llm

# %%
proposition_generator
# Out:
# ChatPromptTemplate(input_variables=['document'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Please break down the following text into simple, self-contained propositions. Ensure that each proposition meets the following criteria:\n\n    1. Express a Single Fact: Each proposition should state one specific fact or claim.\n    2. Be Understandable Without Context: The proposition should be self-contained, meaning it can be understood without needing additional context.\n    3. Use Full Names, Not Pronouns: Avoid pronouns or ambiguous references; use full entity names.\n    4. Include Relevant Dates/Qualifiers: If applicable, include necessary dates, times, and qualifiers to make the fact precise.\n    5. Contain One Subject-Predicate Relationship: Focus on a single subject and its corresponding action or attribute, without conjunctions or multiple clauses.'), additional_kwargs={}), FewShotChatMessagePromptTemplate(examples=[{'document': 'In 1969, Neil Armstrong became the first person to walk on the Moon during the Apollo 11 mission.', 'propositions': "['Neil Armstrong was an astronaut.', 'Neil Armstrong walked on the Moon in 1969.', 'Neil Armstrong was the first person to walk on the Moon.', 'Neil Armstrong walked on the Moon during the Apollo 11 mission.', 'The Apollo 11 mission occurred in 1969.']"}], input_variables=[], input_types={}, partial_variables={}, example_prompt=ChatPromptTemplate(input_variables=['document', 'propositions'], input_types={}, partial_variables={}, messages=[HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['document'], input_types={}, partial_variables={}, template='{document}'), additional_kwargs={}), AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=['propositions'], input_types={}, partial_variables={}, template='{propositions}'), additional_kwargs={})])), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['document'], input_types={}, partial_variables={}, template='{document}'), additional_kwargs={})])
# | RunnableBinding(bound=ChatGroq(client=<groq.resources.chat.completions.Completions object at 0x1715e6f80>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x1715e6d10>, model_name='gemma2-9b-it', model_kwargs={}, groq_api_key=SecretStr('**********')), kwargs={'tools': [{'type': 'function', 'function': {'name': 'GeneratePropositions', 'description': 'List of all the propositions in a given document', 'parameters': {'type': 'object', 'properties': {'propositions': {'description': 'List of propositions (factual, self-contained, and concise information)', 'type': 'array', 'items': {'type': 'string'}}}, 'required': ['propositions']}}}], 'tool_choice': {'type': 'function', 'function': {'name': 'GeneratePropositions'}}}, config={}, config_factories=[])
# | PydanticToolsParser(first_tool_only=True, tools=[<class '__main__.GeneratePropositions'>])

# %%
from tqdm import tqdm

propositions = []

for i in tqdm(range(len(doc_splits))):
            
            doc = doc_splits[i]
            file_name = doc.metadata['file_name']
            file_path = doc.metadata['file_path']
            creation_date = doc.metadata['creation_date']
            last_modified_date = doc.metadata['last_modified_date']
            split_ls = doc.metadata['file_name'].rstrip('.txt').split("_")
            
            
            response = proposition_generator.invoke({"document": doc.page_content}) # Creating proposition
            for proposition in response.propositions:
                propositions.append(Document(proposition, 
                                                  metadata={ 'file_path': file_path,
                    'file_name': file_name,
                    'file_type': 'text/plain',
                    'file_size': 50540,
                    'creation_date': creation_date,
                    'last_modified_date': last_modified_date, "chunk_id": i+1,
                    'ticker': split_ls[-1],
                    'year': int(split_ls[0]),
                    'quarter': int(split_ls[1])
                    }))
# Out:
# 100%|██████████| 30/30 [02:37<00:00,  5.26s/it]

# %%
propositions
# Out:
# [Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 1, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='The Microsoft Fiscal Year 2024 First Quarter Earnings Conference Call is underway.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 1, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='The participants are in a listen-only mode.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 1, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='A question-and-answer session will follow the formal presentation.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 1, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='The conference call is being recorded.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 1, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Brett Iversen, Vice President of Investor Relations, will lead the call.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 2, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Brett Iversen hosted a Microsoft investor call.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 2, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Satya Nadella, Amy Hood, Alice Jolla, and Keith Dolliver joined the call.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 2, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Earnings press release and financial summary slides are available on the Microsoft Investor Relations website.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 2, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Microsoft acquired Activision Blizzard on October 13, 2023.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 2, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='The call discussed non-GAAP financial measures.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 2, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='All growth comparisons were made to the corresponding period last year.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 2, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Growth rates in constant currency were provided when available.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 2, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Prepared remarks were posted to the website after the call.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 2, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='The call was webcast live and recorded.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 2, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Forward-looking statements were made during the call.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 2, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Actual results could differ materially from expectations.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 3, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content="The earnings press release discussed the company's performance."),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 3, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content="The conference call provided comments on the company's performance."),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 3, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content="Risk factors related to the company's performance are listed in the Form 10-K, Form 10-Q, and other SEC filings."),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 3, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='The company does not plan to update any forward-looking statements.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 3, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='The call was transitioned to Satya.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 4, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Satya Nadella is the CEO of Microsoft.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 4, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Microsoft Cloud revenue exceeded $31.8 billion in the last quarter.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 4, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Microsoft Cloud revenue increased by 24% compared to the previous year.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 4, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Microsoft is integrating AI into all levels of its technology stack.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 4, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Azure gained market share as companies move their workloads to the cloud.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 4, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Azure has over 60 data centers worldwide.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 4, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Azure AI offers access to models from OpenAI, Meta, and Hugging Face.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 4, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Over 18,000 organizations use Azure OpenAI services.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 4, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Azure Arc allows customers to run applications across on-premises, edge, and multi-cloud environments.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 4, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Azure Arc has 21,000 customers, a 140% year-over-year increase.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 4, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Azure is the only cloud provider besides Oracle to run Oracle database services.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 4, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='PepsiCo and Vodafone will use Azure for their Oracle databases.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 4, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Azure is a popular choice for SAP workloads.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 4, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Companies like Brother Industries, Hanes, ZEISS, and ZF Group run SAP on Azure.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 4, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Microsoft is helping organizations consolidate their data estate with the Microsoft Intelligent Data Platform.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 5, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Dynamics 365 took share for the 10th consecutive quarter.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 5, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Microsoft is using AI to redefine its role in business applications.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 5, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Microsoft is becoming the Copilot-led business process transformation layer on top of existing CRM systems.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 5, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Sales Copilot helps sellers.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 5, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='More than 15,000 organizations use Sales Copilot, including Rockwell Automation.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 6, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Microsoft is developing Copilot as a business process transformation layer for CRM systems.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 6, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Sales Copilot helps sellers personalize customer interactions based on data from third-party CRMs.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 6, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Over 15,000 organizations use Sales Copilot, including Rockwell Automation, Sandvik Coromant, Securitas, and Teleperformance.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 6, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Copilot is being integrated into Dynamics 365 for tasks such as suggesting actions, content ideas, and providing faster access to business data.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 6, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Dynamics 365 Field Service now includes Copilot to streamline frontline tasks.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 6, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Dragon Ambient eXperience helps clinicians automatically document patient interactions in healthcare.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 6, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='DAX Copilot drafts high-quality clinical notes, increasing physician productivity and reducing burnout.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 6, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Atrium Health uses DAX Copilot, which helps physicians save up to 40 minutes per day in documentation time.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 6, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Microsoft Fabric offers healthcare data solutions that enable providers to unify health data securely and compliantly.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 6, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Northwestern Medicine and SingHealth use Microsoft Fabric for healthcare data solutions.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 6, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Microsoft Cloud for sovereignty provides data sovereignty and encryption controls for public sector customers.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 6, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Copilot is an AI assistant that enhances creativity in Word, analysis in Excel, expression in PowerPoint, productivity in Outlook, and collaboration in Teams.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 6, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Tens of thousands of employees at companies like Bayer, KPMG, Mayo Clinic, Suncorp, and Visa use Copilot.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 6, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='40% of the Fortune 100 are using Copilot.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 6, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Copilot is entering general availability for enterprise customers next week.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 6, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='A new hero experience in Copilot helps employees access their work, data, and knowledge using chat.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 6, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Copilot Lab helps employees develop new work habits for the AI era by improving prompts.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 7, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Neil Armstrong was an astronaut.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 7, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Neil Armstrong walked on the Moon in 1969.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 7, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Neil Armstrong was the first person to walk on the Moon.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 7, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Neil Armstrong walked on the Moon during the Apollo 11 mission.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 7, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='The Apollo 11 mission occurred in 1969.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 8, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Neil Armstrong was an astronaut.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 8, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Neil Armstrong walked on the Moon in 1969.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 8, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Neil Armstrong was the first person to walk on the Moon.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 8, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Neil Armstrong walked on the Moon during the Apollo 11 mission.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 8, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='The Apollo 11 mission occurred in 1969.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 8, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Windows 365 Boot and Switch makes it easier for employees to get a personalized Windows 365 Cloud PC with Copilot on any device.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 8, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Security is the number one priority for CIOs worldwide.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 8, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content="Security Copilot is the industry's first and most advanced generative AI product."),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 8, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Security Copilot is seamlessly integrated with Microsoft 365 Defender.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 8, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Dozens of organizations have been using Copilot in Preview.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 8, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Early feedback on Copilot has been positive.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 8, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Microsoft Sentinel has more than 25,000 customers in revenue.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 8, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Microsoft Sentinel has surpassed $1 billion annual run-rate.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 8, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Membership growth has accelerated each quarter for over two years.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 8, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='LinkedIn introduced new AI-driven features across all of its businesses.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 8, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='AI-assisted messages for recruiters have saved recruiters time.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 8, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='There has been a nearly 80% increase in members watching AI-related learning courses.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 8, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='There are more than 450 million newsletter subscriptions globally.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 8, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Premium subscription sign-ups were up 55% year-over-year.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 8, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='The hiring business took share for the fifth consecutive quarter.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 8, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Copilot for the Web redefines how people use the Internet to search and create.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 8, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Bing users have engaged in more than 1.9 billion chats.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 9, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Microsoft Bing users have engaged in more than 1.9 billion chats.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 9, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Microsoft Edge has gained share for 10 consecutive quarters.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 9, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='This quarter, Microsoft introduced new personalized answers for Bing.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 9, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Microsoft Bing now supports DALL-E 3.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 9, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='More than 1.8 billion images have been created using DALL-E 3.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 9, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Microsoft Copilot and Shopping provide tailored recommendations and better deals.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 9, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content="Bing is expanding to Meta's AI chat experience."),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 9, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content="Bing will provide more up-to-date answers and real-time search information through Meta's AI chat experience."),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 9, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Microsoft is integrating new generation AI into its ad platforms.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 9, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Microsoft is connecting marketers to customer intent in chat experiences.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 9, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Microsoft acquired Activision Blizzard King earlier this month.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 9, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Microsoft aims to bring great games to players everywhere on any endpoint.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 9, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Game Pass redefined how games are distributed, played, and discovered.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 9, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Game Pass set a record for hours played per subscriber this quarter.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 9, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Starfield was released this quarter.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 9, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='More than 11 million people have played Starfield to date.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 9, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Nearly half of Starfield hours played have been on PC.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 9, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content="Game Pass subscriptions reached a record high on Starfield's launch day."),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 9, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Minecraft has surpassed 300 million copies sold.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 9, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content="Microsoft's content portfolio includes franchises like Candy Crush, Diablo, Halo, Warcraft, Elder Scrolls, and Gears of War."),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 9, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Microsoft is expecting a strong first-party holiday lineup.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 9, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Microsoft will introduce more than 100 new products and capabilities at Ignite Conference.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 9, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Microsoft will introduce exciting new AI innovations at Ignite Conference.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 10, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content="This quarter's revenue was $56.5 billion, up 13% and 12% in constant currency."),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 10, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Earnings per share was $2.99 and increased 27% and 26% in constant currency.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 10, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Consistent execution by our sales teams and partners drove a strong start to the fiscal year.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 10, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Results exceeded expectations and we saw share gains again this quarter across many businesses, as customers adopt our innovative solutions to transform their businesses.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 10, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='In our commercial business, the trends from the prior quarter continued.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 10, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='We saw healthy renewals, particularly in Microsoft 365 E5 and growth of new business continued to be moderated for standalone products sold outside the Microsoft 365 suite.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 10, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='In Azure, as expected the optimization trends were similar to Q4.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 10, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Higher-than-expected AI consumption contributed to revenue growth in Azure.'),
# ...
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 26, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Amy Hood said that seat growth has also been strong in frontline worker opportunities.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 26, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Amy Hood said that Microsoft 365 is becoming more applicable to more people.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 26, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Amy Hood said that Microsoft 365 now includes security, analytics, and Teams.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 26, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Amy Hood said that the value of Microsoft 365 is compelling, especially for small businesses.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 26, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Bradley Sills thanked Amy Hood.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 26, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Brett Iversen thanked Bradley Sills.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 26, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='The next question came from Brent Bracelin with Piper Sandler.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 27, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content="Amy Hood answered a question about Azure's operating margins."),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 27, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content="Azure's operating margins were the highest in six years."),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 27, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content="Elevated AI investments did not negatively impact Azure's operating margins."),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 27, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content="Azure's revenue growth and stability contributed to operating leverage."),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 27, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='The Azure team delivered gross margin improvement through technical decisions and software implementations.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 27, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Microsoft is focused on using operating expenses to lead in the AI transition with Azure.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 27, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='AI investments will show up as revenue and COGS.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 27, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='The first two quarters of the year had easier operating expense comparisons from the previous year.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 27, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content="Brent Bracelin asked a question about Azure's operating margins."),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 28, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Gregg Moskowitz is an analyst at Mizuho.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 28, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content="Gregg Moskowitz asked a question about Microsoft's cloud gross margin."),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 28, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content="Microsoft's cloud gross margin increased by 2 percentage points year-over-year, excluding the useful life change."),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 28, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content="Some investors were concerned about Microsoft's cloud gross margin decreasing due to increased AI investments."),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 28, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Amy was asked if Microsoft can continue to improve its cloud gross margin in the medium term.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 28, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content="Higher capital expenditures are expected to impact Microsoft's model."),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 29, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Amy Hood is a business leader at Microsoft.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 29, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Microsoft is improving its gross margins in its core business segments.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 29, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Microsoft is investing in AI.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 29, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content="Microsoft's infrastructure is consistent across its product layers."),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 29, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Microsoft aims to leverage its infrastructure for revenue generation.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 29, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content="Microsoft's AI investments will impact cost of goods sold (COGS)."),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 29, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Microsoft expects revenue growth to align with AI-related COGS growth.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 29, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Microsoft optimizes capital allocation across its segments and products.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 29, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Satya Nadella is the CEO of Microsoft.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 30, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Gregg Moskowitz was a participant in the earnings call.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 30, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Brett Iversen thanked Gregg Moskowitz.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 30, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Brett Iversen stated that the Q&A portion of the earnings call wrapped up.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 30, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Brett Iversen thanked the participants for joining the earnings call.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 30, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Brett Iversen expressed anticipation for speaking with participants again soon.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 30, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Amy Hood thanked the participants.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 30, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Satya Nadella thanked the participants.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 30, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='The operator concluded the conference.')]

# %% [markdown]
# ### Quality Check

# %%
# Data model
class GradePropositions(BaseModel):
    """Grade a given proposition on accuracy, clarity, completeness, and conciseness"""

    accuracy: int = Field(
        description="Rate from 1-10 based on how well the proposition reflects the original text."
    )
    
    clarity: int = Field(
        description="Rate from 1-10 based on how easy it is to understand the proposition without additional context."
    )

    completeness: int = Field(
        description="Rate from 1-10 based on whether the proposition includes necessary details (e.g., dates, qualifiers)."
    )

    conciseness: int = Field(
        description="Rate from 1-10 based on whether the proposition is concise without losing important information."
    )

# LLM with function call
llm = ChatGroq(model="llama-3.1-70b-versatile", temperature=0)
llm = ChatGroq(model='gemma2-9b-it')
structured_llm= llm.with_structured_output(GradePropositions)

# Prompt
evaluation_prompt_template = """
Please evaluate the following proposition based on the criteria below:
- **Accuracy**: Rate from 1-10 based on how well the proposition reflects the original text.
- **Clarity**: Rate from 1-10 based on how easy it is to understand the proposition without additional context.
- **Completeness**: Rate from 1-10 based on whether the proposition includes necessary details (e.g., dates, qualifiers).
- **Conciseness**: Rate from 1-10 based on whether the proposition is concise without losing important information.

Example:
Docs: In 1969, Neil Armstrong became the first person to walk on the Moon during the Apollo 11 mission.

Propositons_1: Neil Armstrong was an astronaut.
Evaluation_1: "accuracy": 10, "clarity": 10, "completeness": 10, "conciseness": 10

Propositons_2: Neil Armstrong walked on the Moon in 1969.
Evaluation_3: "accuracy": 10, "clarity": 10, "completeness": 10, "conciseness": 10

Propositons_3: Neil Armstrong was the first person to walk on the Moon.
Evaluation_3: "accuracy": 10, "clarity": 10, "completeness": 10, "conciseness": 10

Propositons_4: Neil Armstrong walked on the Moon during the Apollo 11 mission.
Evaluation_4: "accuracy": 10, "clarity": 10, "completeness": 10, "conciseness": 10

Propositons_5: The Apollo 11 mission occurred in 1969.
Evaluation_5: "accuracy": 10, "clarity": 10, "completeness": 10, "conciseness": 10

Format:
Proposition: "{proposition}"
Original Text: "{original_text}"
"""
prompt = ChatPromptTemplate.from_messages(
    [
        ("system", evaluation_prompt_template),
        ("human", "{proposition}, {original_text}"),
    ]
)

proposition_evaluator = prompt | structured_llm

# %%
len(doc_splits)
# Out:
# 30

# %%
# Define evaluation categories and thresholds
evaluation_categories = ["accuracy", "clarity", "completeness", "conciseness"]
thresholds = {"accuracy": 7, "clarity": 7, "completeness": 7, "conciseness": 7}

# Function to evaluate proposition
def evaluate_proposition(proposition, original_text):
    response = proposition_evaluator.invoke({"proposition": proposition, "original_text": original_text})
    
    # Parse the response to extract scores
    scores = {"accuracy": response.accuracy, "clarity": response.clarity, "completeness": response.completeness, "conciseness": response.conciseness}  # Implement function to extract scores from the LLM response
    return scores

# Check if the proposition passes the quality check
def passes_quality_check(scores):
    for category, score in scores.items():
        if score < thresholds[category]:
            return False
    return True

evaluated_propositions = [] # Store all the propositions from the document

# Loop through generated propositions and evaluate them
for idx, proposition in enumerate(propositions):
    scores = evaluate_proposition(proposition.page_content, doc_splits[proposition.metadata['chunk_id'] - 1].page_content)
    if passes_quality_check(scores):
        # Proposition passes quality check, keep it
        evaluated_propositions.append(proposition)
        print(f"Success: {idx+1}) Propostion: {proposition.page_content} \n Scores: {scores}")
    else:
        # Proposition fails, discard or flag for further review
        print(f"Fail: {idx+1}) Propostion: {proposition.page_content} \n Scores: {scores}")
# Out:
# Success: 1) Propostion: The Microsoft Fiscal Year 2024 First Quarter Earnings Conference Call is underway.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 2) Propostion: The participants are in a listen-only mode.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 3) Propostion: A question-and-answer session will follow the formal presentation.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 4) Propostion: The conference call is being recorded.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 5) Propostion: Brett Iversen, Vice President of Investor Relations, will lead the call.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 6) Propostion: Brett Iversen hosted a Microsoft investor call.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 7) Propostion: Satya Nadella, Amy Hood, Alice Jolla, and Keith Dolliver joined the call.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 8) Propostion: Earnings press release and financial summary slides are available on the Microsoft Investor Relations website.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 9) Propostion: Microsoft acquired Activision Blizzard on October 13, 2023.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 10) Propostion: The call discussed non-GAAP financial measures.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 11) Propostion: All growth comparisons were made to the corresponding period last year.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 12) Propostion: Growth rates in constant currency were provided when available.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 13) Propostion: Prepared remarks were posted to the website after the call.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 14) Propostion: The call was webcast live and recorded.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 15) Propostion: Forward-looking statements were made during the call.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 16) Propostion: Actual results could differ materially from expectations.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 17) Propostion: The earnings press release discussed the company's performance.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 18) Propostion: The conference call provided comments on the company's performance.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 19) Propostion: Risk factors related to the company's performance are listed in the Form 10-K, Form 10-Q, and other SEC filings.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 20) Propostion: The company does not plan to update any forward-looking statements.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 21) Propostion: The call was transitioned to Satya.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 22) Propostion: Satya Nadella is the CEO of Microsoft.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 23) Propostion: Microsoft Cloud revenue exceeded $31.8 billion in the last quarter.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 24) Propostion: Microsoft Cloud revenue increased by 24% compared to the previous year.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 25) Propostion: Microsoft is integrating AI into all levels of its technology stack.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 26) Propostion: Azure gained market share as companies move their workloads to the cloud.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 27) Propostion: Azure has over 60 data centers worldwide.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 28) Propostion: Azure AI offers access to models from OpenAI, Meta, and Hugging Face.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 29) Propostion: Over 18,000 organizations use Azure OpenAI services.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 30) Propostion: Azure Arc allows customers to run applications across on-premises, edge, and multi-cloud environments.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 31) Propostion: Azure Arc has 21,000 customers, a 140% year-over-year increase.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 32) Propostion: Azure is the only cloud provider besides Oracle to run Oracle database services.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 33) Propostion: PepsiCo and Vodafone will use Azure for their Oracle databases.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 34) Propostion: Azure is a popular choice for SAP workloads.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 35) Propostion: Companies like Brother Industries, Hanes, ZEISS, and ZF Group run SAP on Azure.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 36) Propostion: Microsoft is helping organizations consolidate their data estate with the Microsoft Intelligent Data Platform.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 37) Propostion: Dynamics 365 took share for the 10th consecutive quarter.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 38) Propostion: Microsoft is using AI to redefine its role in business applications.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 39) Propostion: Microsoft is becoming the Copilot-led business process transformation layer on top of existing CRM systems.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 40) Propostion: Sales Copilot helps sellers.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 41) Propostion: More than 15,000 organizations use Sales Copilot, including Rockwell Automation.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 42) Propostion: Microsoft is developing Copilot as a business process transformation layer for CRM systems.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 43) Propostion: Sales Copilot helps sellers personalize customer interactions based on data from third-party CRMs.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 44) Propostion: Over 15,000 organizations use Sales Copilot, including Rockwell Automation, Sandvik Coromant, Securitas, and Teleperformance.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 45) Propostion: Copilot is being integrated into Dynamics 365 for tasks such as suggesting actions, content ideas, and providing faster access to business data.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 46) Propostion: Dynamics 365 Field Service now includes Copilot to streamline frontline tasks.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 47) Propostion: Dragon Ambient eXperience helps clinicians automatically document patient interactions in healthcare.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 48) Propostion: DAX Copilot drafts high-quality clinical notes, increasing physician productivity and reducing burnout.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 49) Propostion: Atrium Health uses DAX Copilot, which helps physicians save up to 40 minutes per day in documentation time.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 50) Propostion: Microsoft Fabric offers healthcare data solutions that enable providers to unify health data securely and compliantly.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 51) Propostion: Northwestern Medicine and SingHealth use Microsoft Fabric for healthcare data solutions.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 52) Propostion: Microsoft Cloud for sovereignty provides data sovereignty and encryption controls for public sector customers.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 53) Propostion: Copilot is an AI assistant that enhances creativity in Word, analysis in Excel, expression in PowerPoint, productivity in Outlook, and collaboration in Teams.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 54) Propostion: Tens of thousands of employees at companies like Bayer, KPMG, Mayo Clinic, Suncorp, and Visa use Copilot.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 55) Propostion: 40% of the Fortune 100 are using Copilot.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 56) Propostion: Copilot is entering general availability for enterprise customers next week.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 57) Propostion: A new hero experience in Copilot helps employees access their work, data, and knowledge using chat.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 58) Propostion: Copilot Lab helps employees develop new work habits for the AI era by improving prompts.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 59) Propostion: Neil Armstrong was an astronaut.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 60) Propostion: Neil Armstrong walked on the Moon in 1969.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 61) Propostion: Neil Armstrong was the first person to walk on the Moon.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 62) Propostion: Neil Armstrong walked on the Moon during the Apollo 11 mission.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 63) Propostion: The Apollo 11 mission occurred in 1969.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 64) Propostion: Neil Armstrong was an astronaut.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 65) Propostion: Neil Armstrong walked on the Moon in 1969.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 66) Propostion: Neil Armstrong was the first person to walk on the Moon.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 67) Propostion: Neil Armstrong walked on the Moon during the Apollo 11 mission.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 68) Propostion: The Apollo 11 mission occurred in 1969.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 69) Propostion: Windows 365 Boot and Switch makes it easier for employees to get a personalized Windows 365 Cloud PC with Copilot on any device.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 70) Propostion: Security is the number one priority for CIOs worldwide.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 71) Propostion: Security Copilot is the industry's first and most advanced generative AI product.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 72) Propostion: Security Copilot is seamlessly integrated with Microsoft 365 Defender.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 73) Propostion: Dozens of organizations have been using Copilot in Preview.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 74) Propostion: Early feedback on Copilot has been positive.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 75) Propostion: Microsoft Sentinel has more than 25,000 customers in revenue.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 76) Propostion: Microsoft Sentinel has surpassed $1 billion annual run-rate.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 77) Propostion: Membership growth has accelerated each quarter for over two years.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 78) Propostion: LinkedIn introduced new AI-driven features across all of its businesses.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 79) Propostion: AI-assisted messages for recruiters have saved recruiters time.
#  Scores: {'accuracy': 8, 'clarity': 9, 'completeness': 9, 'conciseness': 8}
# Success: 80) Propostion: There has been a nearly 80% increase in members watching AI-related learning courses.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 81) Propostion: There are more than 450 million newsletter subscriptions globally.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 82) Propostion: Premium subscription sign-ups were up 55% year-over-year.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 83) Propostion: The hiring business took share for the fifth consecutive quarter.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 84) Propostion: Copilot for the Web redefines how people use the Internet to search and create.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 85) Propostion: Bing users have engaged in more than 1.9 billion chats.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 86) Propostion: Microsoft Bing users have engaged in more than 1.9 billion chats.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 87) Propostion: Microsoft Edge has gained share for 10 consecutive quarters.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 88) Propostion: This quarter, Microsoft introduced new personalized answers for Bing.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 89) Propostion: Microsoft Bing now supports DALL-E 3.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 90) Propostion: More than 1.8 billion images have been created using DALL-E 3.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 91) Propostion: Microsoft Copilot and Shopping provide tailored recommendations and better deals.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 92) Propostion: Bing is expanding to Meta's AI chat experience.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 93) Propostion: Bing will provide more up-to-date answers and real-time search information through Meta's AI chat experience.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 94) Propostion: Microsoft is integrating new generation AI into its ad platforms.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 95) Propostion: Microsoft is connecting marketers to customer intent in chat experiences.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 96) Propostion: Microsoft acquired Activision Blizzard King earlier this month.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 97) Propostion: Microsoft aims to bring great games to players everywhere on any endpoint.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 98) Propostion: Game Pass redefined how games are distributed, played, and discovered.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 99) Propostion: Game Pass set a record for hours played per subscriber this quarter.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 100) Propostion: Starfield was released this quarter.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 101) Propostion: More than 11 million people have played Starfield to date.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 102) Propostion: Nearly half of Starfield hours played have been on PC.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 103) Propostion: Game Pass subscriptions reached a record high on Starfield's launch day.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 104) Propostion: Minecraft has surpassed 300 million copies sold.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 105) Propostion: Microsoft's content portfolio includes franchises like Candy Crush, Diablo, Halo, Warcraft, Elder Scrolls, and Gears of War.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 106) Propostion: Microsoft is expecting a strong first-party holiday lineup.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 107) Propostion: Microsoft will introduce more than 100 new products and capabilities at Ignite Conference.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 108) Propostion: Microsoft will introduce exciting new AI innovations at Ignite Conference.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 109) Propostion: This quarter's revenue was $56.5 billion, up 13% and 12% in constant currency.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 110) Propostion: Earnings per share was $2.99 and increased 27% and 26% in constant currency.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 111) Propostion: Consistent execution by our sales teams and partners drove a strong start to the fiscal year.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 112) Propostion: Results exceeded expectations and we saw share gains again this quarter across many businesses, as customers adopt our innovative solutions to transform their businesses.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 113) Propostion: In our commercial business, the trends from the prior quarter continued.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 114) Propostion: We saw healthy renewals, particularly in Microsoft 365 E5 and growth of new business continued to be moderated for standalone products sold outside the Microsoft 365 suite.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 115) Propostion: In Azure, as expected the optimization trends were similar to Q4.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 116) Propostion: Higher-than-expected AI consumption contributed to revenue growth in Azure.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 117) Propostion: And our consumer business, PC market unit volumes are returning to pre-pandemic levels.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 118) Propostion: Advertising spend, landed roughly in line with our expectations and in gaming strong engagement helped by the Starfield launch benefited Xbox content and services.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 119) Propostion: Commercial bookings increased 14% and 17% in constant currency, in line with expectations, primarily driven by strong execution across our core annuity sales motions, with continued growth in the number of $10 million plus contracts for both Azure and Microsoft 365.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 120) Propostion: Commercial remaining performance obligation, increased 18% to $212 billion, and roughly 45% will be recognized in revenue in the next 12 months, up 15% year-over-year.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 121) Propostion: The remaining portion, which will be recognized beyond the next 12 months increased 20% and this quarter, our annuity mix was 96%.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 122) Propostion: FX did not have a significant impact on our results and was roughly in line with our expectations on total company revenue, segment-level revenue, COGS, and operating expense growth.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 123) Propostion: Microsoft Cloud revenue was $31.8 billion and grew 24% and 23% in constant currency, ahead of expectations.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 124) Propostion: Microsoft Cloud's gross margin percentage increased slightly year-over-year to 73%, a point better than expected, primarily driven by improvements in Azure.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 125) Propostion: Excluding the impact of the change in accounting estimate for useful lives, Microsoft Cloud's gross margin percentage increased roughly 2 points, driven by the improvement just mentioned in Azure as well as Office 365, partially offset by the impact of scaling our AI infrastructure to meet growing demand.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 126) Propostion: Company gross margin dollars increased 16% and 15% in constant currency and gross margin percentage increased year-over-year year-over-year
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 127) Propostion: Company gross margin dollars increased by 16% and 15% in constant currency.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 128) Propostion: Gross margin percentage increased year-over-year to 71%.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 129) Propostion: Operating expenses increased by 1%, lower than expected.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 130) Propostion: Operating income increased by 25% and 24% in constant currency.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 131) Propostion: Operating margins increased roughly 5 points year-over-year to 48%.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 132) Propostion: Revenue from Productivity and Business Processes was $18.6 billion and grew by 13% and 12% in constant currency.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 133) Propostion: Office Commercial revenue grew by 15% and 14% in constant currency.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 134) Propostion: Office 365 Commercial revenue increased by 18% and 17% in constant currency.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 135) Propostion: Paid Office 365 Commercial seats grew by 10% year-over-year.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 136) Propostion: Office Commercial licensing declined by 17%.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 137) Propostion: Office Consumer revenue increased by 3% and 4% in constant currency.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 138) Propostion: Microsoft 365 subscriptions grew by 18% to 76.7 million.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 139) Propostion: LinkedIn revenue increased by 8%.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 140) Propostion: Revenue for the company increased year-over-year.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 141) Propostion: Talent Solutions experienced growth despite negative year-over-year bookings.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 142) Propostion: Dynamics revenue grew 22% year-over-year.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 143) Propostion: Dynamics 365 grew 28% year-over-year in constant currency.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 144) Propostion: Segment gross margin dollars increased 13% year-over-year.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 145) Propostion: Operating expenses increased 2% year-over-year.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 146) Propostion: Operating income increased 20% year-over-year.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 147) Propostion: Intelligent Cloud segment revenue was $24.3 billion and increased 19% year-over-year.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 148) Propostion: Overall server products and cloud services revenue grew 21% year-over-year.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 149) Propostion: Azure and other cloud services revenue grew 29% year-over-year in constant currency.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 150) Propostion: AI Services contributed approximately 3 percentage points to Azure and other cloud services revenue growth.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 151) Propostion: Enterprise mobility and security installed base grew 11% to over 259 million seats.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 152) Propostion: On-premises server business revenue increased 2% year-over-year.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 153) Propostion: Enterprise and partner services revenue increased 1% year-over-year.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 154) Propostion: More Personal Computing segment revenue was $13.7 billion and increased 3% year-over-year.
#  Scores: {'accuracy': 10, 'clarity': 9, 'completeness': 9, 'conciseness': 9}
# Success: 155) Propostion: Windows OEM revenue increased 4% year-over-year.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 156) Propostion: The Activision acquisition closed on October 13.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 157) Propostion: The commentary will be based on the U.S. dollar basis.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 158) Propostion: The outlook is for Q2.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 159) Propostion: Microsoft paid $9.1 billion to shareholders through share repurchases and dividends.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 160) Propostion: The Activision acquisition closed on October 13.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 161) Propostion: The outlook includes the net impact of the Activision acquisition from October 13.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 162) Propostion: The net impact adjusts for the movement of Activision content from a third-party to first-party.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 163) Propostion: Foreign exchange is expected to increase total revenue and segment-level revenue growth by approximately 1 point.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 164) Propostion: Foreign exchange is not expected to impact cost of goods sold or operating expense growth.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 165) Propostion: Commercial bookings growth is expected to be relatively flat.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 166) Propostion: Microsoft Cloud gross margin percentage is expected to be relatively flat year-over-year, excluding the impact from the accounting estimate change.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 167) Propostion: Q2 Cloud gross margin percentage is expected to be up roughly 1 point.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 168) Propostion: Capital expenditures are expected to increase sequentially on a dollar basis.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 169) Propostion: Productivity and Business Processes revenue is expected to grow between 11% and 12% or $18.8 billion to $19.1 billion.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 170) Propostion: Office Commercial revenue growth will be driven by Office 365 with seat growth across customer segments and ARPU growth through E5.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 171) Propostion: Office 365 revenue growth is expected to be up roughly 16% in constant currency.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 172) Propostion: Microsoft 365 Copilot general availability is on November 1st.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 173) Propostion: On-premise Office revenue is expected to decline in the mid-to-high teens.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 174) Propostion: Office Consumer revenue is expected to grow in the mid-single-digits.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 175) Propostion: LinkedIn revenue growth is expected in the mid-single-digits.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 176) Propostion: LinkedIn Talent Solutions and Marketing Solutions are driving revenue growth.
#  Scores: {'accuracy': 8, 'clarity': 8, 'completeness': 8, 'conciseness': 8}
# Success: 177) Propostion: Office Consumer revenue growth is expected in the mid-single-digits, driven by Microsoft 365 subscriptions.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 178) Propostion: LinkedIn revenue growth is expected in the mid-single-digits, driven by Talent Solutions and Marketing Solutions.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 179) Propostion: Growth in Office Consumer, LinkedIn, and Dynamics is impacted by the overall market environment for recruiting and advertising.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 180) Propostion: Dynamics revenue growth is expected in the high teens, driven by Dynamics 365.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 181) Propostion: Intelligent Cloud revenue is expected to grow between 17% and 18% or $25.1 billion to $25.4 billion.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 182) Propostion: Revenue growth in constant currency for Intelligent Cloud will be approximately 1 point lower.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 183) Propostion: Azure revenue growth is expected to be 26% to 27% in constant currency.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 184) Propostion: Growth in Azure is driven by Azure consumption business.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 185) Propostion: Azure per-user business should benefit from Microsoft 365 suite momentum.
#  Scores: {'accuracy': 8, 'clarity': 9, 'completeness': 8, 'conciseness': 9}
# Success: 186) Propostion: Seat growth rates are expected to moderate.
#  Scores: {'accuracy': 8, 'clarity': 9, 'completeness': 7, 'conciseness': 9}
# Success: 187) Propostion: Azure revenue growth in constant currency is expected to remain roughly stable compared to Q2 in H2.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 188) Propostion: On-premises server business revenue is expected to be roughly flat.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 189) Propostion: Enterprise and partner services revenue should decline by low-to-mid single digits.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 190) Propostion: Personal Computing revenue is expected to be $16.5 billion to $16.9 billion.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 191) Propostion: Windows OEM revenue growth should be mid-to-high single digits.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 192) Propostion: PC market unit volumes are expected to look roughly similar to Q1.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 193) Propostion: Devices revenue should decline in the mid-teens.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 194) Propostion: Customer demand for Microsoft 365 and advanced security solutions should drive revenue growth in Windows Commercial products and cloud services.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 195) Propostion: Search and news advertising ex-TAC revenue growth should be mid-single digits.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 196) Propostion: Search and news advertising ex-TAC revenue growth should be impacted by a third-party partnership.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 197) Propostion: Microsoft expects teens to search and news advertising revenue growth to be in the mid-single digits.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 198) Propostion:  Microsoft predicts a four-point negative impact on growth from a third-party partnership.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 199) Propostion: Volume strength, Edge browser share gains, and increasing Bing engagement are expected to drive growth.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 200) Propostion: The advertising spend environment is anticipated to be similar to Q1.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 201) Propostion: Ex-TAC growth is projected to be four points higher than overall search and news advertising revenue.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 202) Propostion: Gaming revenue growth is forecasted in the mid-to-high 40s.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 203) Propostion: The Activision acquisition is expected to contribute approximately 35 points of net impact to gaming revenue growth.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 204) Propostion: Xbox content and services revenue growth is anticipated in the mid-to-high 50s.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 205) Propostion: The Activision acquisition is expected to contribute around 50 points of net impact to Xbox content and services revenue growth.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 206) Propostion: Microsoft anticipates COGS between $19.4 billion and $19.6 billion.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 207) Propostion: Amortization of acquired intangible assets from the Activision acquisition is estimated at $500 million.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 208) Propostion: Operating expenses are projected to be $15.5 billion to $15.6 billion.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 209) Propostion: Purchase accounting adjustments, integration, and transaction-related costs from the Activision acquisition are estimated at $400 million.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 210) Propostion: Other income and expense is anticipated to be roughly negative $500 million.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 211) Propostion: Interest income is expected to be outweighed by interest expense due to a decrease in the investment portfolio balance and issuance of short-term debt for the Activision acquisition.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 212) Propostion: Gains or losses on equity investments can increase quarterly volatility.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 213) Propostion: The Q2 effective tax rate is projected to be between 19% and 20%.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 214) Propostion: Assuming current rates remain stable, FX is expected to have no meaningful impact on full-year revenue, COGS, or operating expense growth.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 215) Propostion: FX is anticipated to decrease revenue, COGS, and operating expense growth by 1 point in H2.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 216) Propostion: Approximately $900 million is expected for purchase accounting adjustments and integration and transaction-related costs in each quarter of H2 due to the Activision acquisition.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 217) Propostion: For fiscal year '24, Microsoft remains committed to investing in the cloud and AI opportunity while maintaining a disciplined focus on operating leverage.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 218) Propostion: Including the net impact of Activision, Microsoft expects full-year operating margins to remain flat.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 219) Propostion: AI opportunity
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 220) Propostion: operating leverage
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Fail: 221) Propostion: Activision
#  Scores: {'accuracy': 1, 'clarity': 1, 'completeness': 1, 'conciseness': 1}
# Success: 222) Propostion: purchase accounting adjustments
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 223) Propostion: integration and transaction-related expenses
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 224) Propostion: full year operating margins
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 225) Propostion: commercial cloud
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 226) Propostion: AI platform wave
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 227) Propostion: Q&A
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 228) Propostion: Brett
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 229) Propostion: Keith Weiss is an analyst at Morgan Stanley.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 230) Propostion: Keith Weiss complimented the company on their innovation and product traction.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 231) Propostion: Keith Weiss is concerned about the volatile spending environment.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 232) Propostion: Keith Weiss asked about the sustainability of the company's commercial growth.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 233) Propostion: Amy has been able to keep operating expenses low.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 234) Propostion: Satya Nadella is leading Microsoft.
#  Scores: {'accuracy': 8, 'clarity': 8, 'completeness': 8, 'conciseness': 8}
# Success: 235) Propostion: Microsoft Azure is experiencing growth.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 236) Propostion: Cloud migrations are driving Azure growth.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 237) Propostion: Oracle databases are becoming available on Azure.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 238) Propostion: Financial services are a sector with significant Oracle estates.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 239) Propostion: Workloads on Azure are being optimized.
#  Scores: {'accuracy': 8, 'clarity': 7, 'completeness': 7, 'conciseness': 8}
# Success: 240) Propostion: New workloads are starting on Azure.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 241) Propostion: AI workloads are driving new projects on Azure.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 242) Propostion: AI projects require multiple cloud resources.
#  Scores: {'accuracy': 8, 'clarity': 9, 'completeness': 7, 'conciseness': 8}
# Success: 243) Propostion: Microsoft is seeing success with AI-driven products.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 244) Propostion: GitHub Copilot is demonstrating the productivity benefits of AI.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 245) Propostion: Microsoft's SaaS products are in the early stages of adoption.
#  Scores: {'accuracy': 8, 'clarity': 9, 'completeness': 8, 'conciseness': 9}
# Success: 246) Propostion: Customers are confident in the value of Microsoft's AI products.
#  Scores: {'accuracy': 8, 'clarity': 7, 'completeness': 7, 'conciseness': 8}
# Success: 247) Propostion: Amy Hood is a speaker in a conference call.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 248) Propostion: Amy Hood discussed the value proposition of Microsoft.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 249) Propostion: Amy Hood spoke about operational leverage.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 250) Propostion: Amy Hood mentioned consistent execution from Q4 to Q1.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 251) Propostion: Amy Hood highlighted the importance of customer return on value.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 252) Propostion: Amy Hood discussed full-year guidance and operating margins.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 253) Propostion: Amy Hood talked about the impact of Activision acquisition.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 254) Propostion: Amy Hood mentioned improvements in Azure and Microsoft 365 gross margins.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 255) Propostion: Amy Hood discussed the pace of AI revenue delivery.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 256) Propostion: Amy Hood addressed challenges with operating expense comparables in H2.
#  Scores: {'accuracy': 8, 'clarity': 9, 'completeness': 7, 'conciseness': 8}
# Success: 257) Propostion: Amy Hood emphasized prioritization of commercial cloud leadership and AI.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 258) Propostion: Keith Weiss is a questioner in the conference call.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 259) Propostion: Brett Iversen facilitated the conference call.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 260) Propostion: Mark Moerdler asked a question during the conference call.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 261) Propostion: Satya Nadella responded to a question about Microsoft's AI strategy.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 262) Propostion: Microsoft uses a full-stack approach to AI, from development to deployment.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 263) Propostion: Microsoft leverages a single large model for both training and inference across its AI services.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 264) Propostion: Copilot and Copilot stack are built on the same model.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 265) Propostion: Microsoft offers open-source models and supports fine-tuning and RLHF.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 266) Propostion: Azure AI service is a platform for accessing Microsoft's AI capabilities.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 267) Propostion: Amy Hood and Satya Nadella spoke at a Microsoft earnings call.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 268) Propostion: Investors asked about Microsoft's revenue growth.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 269) Propostion: Amy Hood stated that Microsoft's Azure cloud computing business is expected to grow steadily in the second half of the year.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 270) Propostion: Satya Nadella emphasized the importance of discipline in Microsoft's capital spending for the AI transition.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 271) Propostion: Brett Iversen thanked Brent.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 272) Propostion: Joe asked the next question.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 273) Propostion: The next question came from Raimo Lenschow with Barclays.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 274) Propostion: Raimo Lenschow asked a question about the opportunity in the office space with Copilot.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 275) Propostion: Copilot is coming out very soon.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 276) Propostion: Raimo Lenschow wanted to know how excited customers were about Copilot.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 277) Propostion: Raimo Lenschow asked about the special features of Copilot.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 278) Propostion: Raimo Lenschow wanted to know what Copilot's adoption curve would be like.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 279) Propostion: Copilot will go GA on November 1st.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 280) Propostion: Satya Nadella is the CEO of Microsoft.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 281) Propostion: Microsoft is releasing a new product called Copilot.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 282) Propostion: Copilot is an AI-powered productivity tool.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 283) Propostion: 40% of the Fortune 100 companies are already using Copilot in preview.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 284) Propostion: Copilot is available across multiple Microsoft products, including Word, Excel, PowerPoint, Outlook, and Teams.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 285) Propostion: Copilot's intelligent recap feature for Teams meetings provides a searchable knowledge base of meeting discussions.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 286) Propostion: Copilot is helping users across different functions, such as finance and sales, achieve productivity gains.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 287) Propostion: Microsoft is excited about the adoption and feedback for Copilot.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 288) Propostion: Microsoft will showcase more Copilot use cases and guidance at its Ignite conference.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 289) Propostion: Copilot is an enterprise product with an incremental pricing model.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 290) Propostion: The early adoption and excitement for Copilot are positive signs for Microsoft.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 291) Propostion: Karl Keirstead asked about Azure's growth outlook.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 292) Propostion: Amy Hood stated that Azure growth is expected to stabilize after December.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 293) Propostion: Amy Hood attributed the stabilization to continued customer optimization of Azure spending.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 294) Propostion: Amy Hood mentioned that new workload starts, particularly AI workloads, will drive Azure growth.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 295) Propostion: Amy Hood believes that Microsoft is well-positioned to take share in the Azure market.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 296) Propostion: Karl Keirstead asked a question.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 297) Propostion: Brett Iversen thanked Karl Keirstead.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 298) Propostion: The next question came from Bradley Sills with Bank of America.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 299) Propostion: Bradley Sills asked about Office 365 commercial seat growth.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 300) Propostion: Amy Hood answered Bradley Sills' question.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 301) Propostion: Amy Hood said that seat growth comes from all segments but is particularly strong in small and mid-sized businesses.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 302) Propostion: Amy Hood said that seat growth has also been strong in frontline worker opportunities.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 303) Propostion: Amy Hood said that Microsoft 365 is becoming more applicable to more people.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 304) Propostion: Amy Hood said that Microsoft 365 now includes security, analytics, and Teams.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 305) Propostion: Amy Hood said that the value of Microsoft 365 is compelling, especially for small businesses.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 306) Propostion: Bradley Sills thanked Amy Hood.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 307) Propostion: Brett Iversen thanked Bradley Sills.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 308) Propostion: The next question came from Brent Bracelin with Piper Sandler.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 309) Propostion: Amy Hood answered a question about Azure's operating margins.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 310) Propostion: Azure's operating margins were the highest in six years.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 311) Propostion: Elevated AI investments did not negatively impact Azure's operating margins.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 312) Propostion: Azure's revenue growth and stability contributed to operating leverage.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 313) Propostion: The Azure team delivered gross margin improvement through technical decisions and software implementations.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 314) Propostion: Microsoft is focused on using operating expenses to lead in the AI transition with Azure.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 315) Propostion: AI investments will show up as revenue and COGS.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 316) Propostion: The first two quarters of the year had easier operating expense comparisons from the previous year.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 317) Propostion: Brent Bracelin asked a question about Azure's operating margins.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 318) Propostion: Gregg Moskowitz is an analyst at Mizuho.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 319) Propostion: Gregg Moskowitz asked a question about Microsoft's cloud gross margin.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 320) Propostion: Microsoft's cloud gross margin increased by 2 percentage points year-over-year, excluding the useful life change.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 321) Propostion: Some investors were concerned about Microsoft's cloud gross margin decreasing due to increased AI investments.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 322) Propostion: Amy was asked if Microsoft can continue to improve its cloud gross margin in the medium term.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 323) Propostion: Higher capital expenditures are expected to impact Microsoft's model.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 324) Propostion: Amy Hood is a business leader at Microsoft.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 325) Propostion: Microsoft is improving its gross margins in its core business segments.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 326) Propostion: Microsoft is investing in AI.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 327) Propostion: Microsoft's infrastructure is consistent across its product layers.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 328) Propostion: Microsoft aims to leverage its infrastructure for revenue generation.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 329) Propostion: Microsoft's AI investments will impact cost of goods sold (COGS).
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 330) Propostion: Microsoft expects revenue growth to align with AI-related COGS growth.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 331) Propostion: Microsoft optimizes capital allocation across its segments and products.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 332) Propostion: Satya Nadella is the CEO of Microsoft.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 333) Propostion: Gregg Moskowitz was a participant in the earnings call.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 334) Propostion: Brett Iversen thanked Gregg Moskowitz.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 335) Propostion: Brett Iversen stated that the Q&A portion of the earnings call wrapped up.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 336) Propostion: Brett Iversen thanked the participants for joining the earnings call.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 337) Propostion: Brett Iversen expressed anticipation for speaking with participants again soon.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 338) Propostion: Amy Hood thanked the participants.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 339) Propostion: Satya Nadella thanked the participants.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}
# Success: 340) Propostion: The operator concluded the conference.
#  Scores: {'accuracy': 10, 'clarity': 10, 'completeness': 10, 'conciseness': 10}

# %%
filtered_propositions = []

for doc in evaluated_propositions:
    if doc.metadata['chunk_id'] == 4:
        filtered_propositions.append(doc)

# %%
doc_splits[4].page_content
# Out:
# "Amy Hood: Thank you, Satya, and good afternoon, everyone. This quarter's revenue was $56.5 billion, up 13% and 12% in constant currency. Earnings per share was $2.99 and increased 27% and 26% in constant currency. Consistent execution by our sales teams and partners drove a strong start to the fiscal year. Results exceeded expectations and we saw share gains again this quarter across many businesses, as customers adopt our innovative solutions to transform their businesses. In our commercial business, the trends from the prior quarter continued. We saw healthy renewals, particularly in Microsoft 365 E5 and growth of new business continued to be moderated for standalone products sold outside the Microsoft 365 suite. In Azure, as expected the optimization trends were similar to Q4. Higher-than-expected AI consumption contributed to revenue growth in Azure. And our consumer business, PC market unit volumes are returning to pre-pandemic levels. Advertising spend, landed roughly in line with our expectations and in gaming strong engagement helped by the Starfield launch benefited Xbox content and services. Commercial bookings increased 14% and 17% in constant currency, in line with expectations, primarily driven by strong execution across our core annuity sales motions, with continued growth in the number of $10 million plus contracts for both Azure and Microsoft 365. Commercial remaining performance obligation, increased 18% to $212 billion, and roughly 45% will be recognized in revenue in the next 12 months, up 15% year-over-year. The remaining portion, which will be recognized beyond the next 12 months increased 20% and this quarter, our annuity mix was 96%. FX did not have a significant impact on our results and was roughly in line with our expectations on total company revenue, segment-level revenue, COGS, and operating expense growth. Microsoft Cloud revenue was $31.8 billion and grew 24% and 23% in constant currency, ahead of expectations. Microsoft Cloud's gross margin percentage increased slightly year-over-year to 73%, a point better than expected, primarily driven by improvements in Azure. Excluding the impact of the change in accounting estimate for useful lives, Microsoft Cloud's gross margin percentage increased roughly 2 points, driven by the improvement just mentioned in Azure as well as Office 365, partially offset by the impact of scaling our AI infrastructure to meet growing demand. Company gross margin dollars increased 16% and 15% in constant currency and gross margin percentage increased year-over-year to 71%. Excluding the impact of the change in accounting estimate, the gross margin percentage increased roughly 3 points, driven by the improvement in Azure and Office 365 as well as sales mix shift to higher margin businesses. Operating expenses increased 1%, lower than expected due to cost-efficiency focus as well as investments that shifted to future quarters. Operating expense growth was driven by marketing, LinkedIn, and cloud engineering, partially offset by devices. At a total company level, headcount at the end of September was 7% lower than a year ago. Operating income increased 25% and 24% in constant currency. Operating margins increased roughly 5 points year-over-year to 48%. Excluding the impact of the change in accounting estimate, operating margins increased roughly 6 six points, driven by improved operating leverage through cost management and the higher gross margin noted earlier. Now to our segment results. Revenue from Productivity and Business Processes was $18.6 billion and grew 13% and 12% in constant currency, ahead of expectations, driven by better-than-expected results in Office 365 Commercial and LinkedIn. Office Commercial revenue grew 15% and 14% in constant currency. Office 365 Commercial revenue increased 18% and 17% in constant currency, slightly better than expected with a bit more in-period revenue recognition, while billings remained relatively in line with expectations. Growt ...

# %%
filtered_propositions
# Out:
# [Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 4, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Microsoft Copilot is integrated with Microsoft 365 Defender.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 4, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Dozens of organizations, including Bridgewater, Fidelity National Financial, and the Government of Alberta, have used Copilot in Preview.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 4, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Early feedback on Copilot has been positive.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 4, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Microsoft plans to make Copilot available to hundreds of organizations in an early access program.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 4, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='The goal of the early access program is to improve the productivity of security operation centers and stop threats at machine speeds.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 4, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Microsoft Sentinel has more than 25,000 customers.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 4, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Microsoft Sentinel revenue has surpassed $1 billion annual run-rate.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 4, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Customers in every industry, including Booz Allen Hamilton, Grant Thornton, and MetLife, use Microsoft Sentinel.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 4, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='LinkedIn membership growth has accelerated each quarter for over two years.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 4, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='LinkedIn introduced new AI-driven features this quarter.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 4, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='The new LinkedIn learning coach provides personalized content guidelines.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 4, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='LinkedIn tools help employers find qualified candidates.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 4, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='LinkedIn tools help sellers and marketers attract buyers in a single step.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 4, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Three-fourths of recruiters who use AI-assisted messages say it saves them time.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 4, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='There has been a nearly 80% increase in members watching AI-related learning courses this quarter.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 4, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='LinkedIn has more than 450 million newsletter subscriptions globally.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 4, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='LinkedIn newsletter subscriptions have increased 3x year-over-year.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 4, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Premium subscription sign-ups for LinkedIn have increased 55% year-over-year.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 4, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content="LinkedIn's hiring business has taken share for the fifth consecutive quarter."),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 4, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Microsoft Copilot for the Web redefines how people use the internet to search and create.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 4, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Bing users have engaged in more than 1.9 billion chats.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 4, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Microsoft Edge has gained share for 10 consecutive quarters.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 4, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Microsoft introduced new personalized answers and DALL-E 3 support for Bing this quarter.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 4, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='More than 1.8 billion images have been created using DALL-E 3.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 4, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Microsoft Copilot and Shopping helps people find more tailored recommendations and better deals.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 4, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content="Bing is being integrated into Meta's AI chat experience."),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 4, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content="Bing provides more up-to-date answers and access to real-time search information in Meta's AI chat experience."),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 4, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Microsoft is integrating AI directly into its ad platforms.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 4, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Microsoft is connecting marketers to customer intent in chat experiences.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 4, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Microsoft acquired Activision Blizzard King earlier this month.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 4, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Microsoft and Activision Blizzard King will advance the goal of bringing great games to players everywhere on any endpoint.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 4, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Game Pass is redefining how games are distributed, played, and discovered.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 4, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Game Pass set a record for hours played per subscriber this quarter.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 4, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Starfield was released this quarter to broad acclaim.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 4, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='More than 11 million people have played Starfield to date.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 4, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Nearly half of the hours played in Starfield have been on PC.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 4, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Game Pass set a record for the most subscriptions added on a single day on the launch day of Starfield.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 4, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Minecraft has now surpassed 300 million copies sold.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 4, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Microsoft will have $13 billion-plus franchises from Candy Crush, Diablo, and Halo to Warcraft, Elder Scrolls, and Gears of War.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 4, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='Microsoft is looking forward to one of its strongest first-party holiday lineups ever.'),
#  Document(metadata={'file_path': '/Users/michieldekoninck/code/Michiel-DK/transcripts_rag/data/2024_1_MSFT.txt', 'file_name': '2024_1_MSFT.txt', 'file_type': 'text/plain', 'file_size': 50540, 'creation_date': '2024-09-18', 'last_modified_date': '2024-09-18', 'chunk_id': 4, 'ticker': 'MSFT', 'year': 2024, 'quarter': 1}, page_content='New titles like Call of Duty: Modern Warfare 3 and Forza Motorsport will be released during the holiday season.')]

# %% [markdown]
# ### Embedding propositions in a vectorstore

# %%
# Add to vectorstore
vectorstore_propositions = FAISS.from_documents(evaluated_propositions, embedding_model)
retriever_propositions = vectorstore_propositions.as_retriever(
                search_type="similarity",
                search_kwargs={'k': 10}, # number of documents to retrieve
            )
# Out:
# OllamaEmbeddings: 100%|██████████| 284/284 [00:08<00:00, 35.09it/s]

# %%
vectorstore_propositions

# %%
query_incr = "Which segments increased year over year"
res_proposition = retriever_propositions.invoke(query_incr)
# Out:
# OllamaEmbeddings: 100%|██████████| 1/1 [00:00<00:00,  6.67it/s]

# %%
for i, r in enumerate(res_proposition):
    print(f"{i+1}) Content: {r.page_content} --- Chunk_id: {r.metadata['chunk_id']}")
# Out:
# 1) Content: Client segment revenue increased by 85% year-over-year. --- Chunk_id: 2
# 2) Content: Client segment revenue increased by 85% year-over-year in the fourth quarter of 2024. --- Chunk_id: 4
# 3) Content: Operating expenses increased by 10% year-over-year in the fourth quarter of 2024. --- Chunk_id: 4
# 4) Content: Diluted earnings per share increased by 3% year-over-year in the fourth quarter of 2024. --- Chunk_id: 4
# 5) Content: Data Center segment operating income increased by 266% year-over-year in the fourth quarter of 2024. --- Chunk_id: 4
# 6) Content: Embedded segment revenue decreased by 46% year-over-year in the fourth quarter of 2024. --- Chunk_id: 4
# 7) Content: Data Center revenue increased by 80% year-over-year in the fourth quarter of 2024. --- Chunk_id: 4
# 8) Content: The Data Center segment will grow double digit sequentially in the June quarter. --- Chunk_id: 12
# 9) Content: AMD's gross margin expanded 230 basis points year-over-year in the first quarter of 2024. --- Chunk_id: 3
# 10) Content: Embedded segment revenue decreased by 20% sequentially in the fourth quarter of 2024. --- Chunk_id: 4

# %%
doc_splits[4]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 doc_splits[4]
#
# NameError: name 'doc_splits' is not defined

# %%
query_decr = "Which segments decreased year over year"
res_proposition = retriever_propositions.invoke(query_decr)
for i, r in enumerate(res_proposition):
    print(f"{i+1}) Content: {r.page_content} --- Chunk_id: {r.metadata['chunk_id']}")
# Out:
# OllamaEmbeddings: 100%|██████████| 1/1 [00:00<00:00, 13.25it/s]
# 1) Content: Embedded segment revenue decreased by 46% year-over-year in the fourth quarter of 2024. --- Chunk_id: 4
# 2) Content: Embedded segment revenue decreased by 20% sequentially in the fourth quarter of 2024. --- Chunk_id: 4
# 3) Content: Client segment revenue declined by 6% sequentially in the fourth quarter of 2024. --- Chunk_id: 4
# 4) Content: AMD's Embedded segment revenue decreased 46% year-over-year. --- Chunk_id: 3
# 5) Content: Gaming segment revenue decreased by 48% year-over-year in the fourth quarter of 2024. --- Chunk_id: 4
# 6) Content: Client segment revenue declined 6% sequentially. --- Chunk_id: 2
# 7) Content: Gaming segment revenue decreased by 33% sequentially in the fourth quarter of 2024. --- Chunk_id: 4
# 8) Content: AMD's Embedded segment revenue decreased 20% sequentially. --- Chunk_id: 3
# 9) Content: The second half of the year is expected to be lower than the first half for the Gaming business. --- Chunk_id: 10
# 10) Content: Client segment revenue increased by 85% year-over-year. --- Chunk_id: 2

# %%
query_decr = "Performance compared to major competitors"
res_proposition = retriever_propositions.invoke(query_decr)
for i, r in enumerate(res_proposition):
    print(f"{i+1}) Content: {r.page_content} --- Chunk_id: {r.metadata['chunk_id']}")
# Out:
# OllamaEmbeddings: 100%|██████████| 1/1 [00:00<00:00, 16.51it/s]
# 1) Content: AMD's EPYC processors can deliver the same amount of compute with 45% fewer servers compared to the competition. --- Chunk_id: 1
# 2) Content: AMD's performance and performance per watt give its customers a TCO advantage. --- Chunk_id: 11
# 3) Content: AMD's experience across a large footprint of customers is an advantage over internal ASICs. --- Chunk_id: 6
# 4) Content: AMD is well positioned to play in large scale systems. --- Chunk_id: 12
# 5) Content: AMD's primary competitor has announced a multiyear road map. --- Chunk_id: 6
# 6) Content: AMD believes they have the technology to be competitive in large training environments. --- Chunk_id: 12
# 7) Content: AMD's competitor's Server CPU business declined more than twice as much as AMD's in the March quarter. --- Chunk_id: 11
# 8) Content: AMD's sweet spot is in the highest performance, high core count, energy efficiency space. --- Chunk_id: 7
# 9) Content: MI300 is the fastest-ramping product in AMD history. --- Chunk_id: 2
# 10) Content: A competitor is launching a high core count product in the coming quarter. --- Chunk_id: 11

# %% [markdown]
# ### Comparing performance with larger chunks size

# %%
# Add to vectorstore_larger_
vectorstore_larger = FAISS.from_documents(doc_splits, embedding_model)
retriever_larger = vectorstore_larger.as_retriever(
                search_type="similarity",
                search_kwargs={'k': 10}, # number of documents to retrieve
            )
# Out:
# OllamaEmbeddings: 100%|██████████| 12/12 [00:01<00:00,  7.39it/s]

# %%
res_larger = retriever_larger.invoke(query)
# Out:
# OllamaEmbeddings: 100%|██████████| 1/1 [00:00<00:00, 80.99it/s]

# %%
for i, r in enumerate(res_larger):
    print(f"{i+1}) Content: {r.page_content} --- Chunk_id: {r.metadata['chunk_id']}")
# Out:
# 1) Content: And we're also -- we've traditionally been very strong in, let's call it, cloud first-party workloads, and that is now extending to cloud third-party workloads, where we see enterprises who are, let's call it, in more of a hybrid environment, adopting AMD both in the cloud and on-prem. So I think, overall, we see it as a continued good progression for us with the server business going through 2024 and beyond.
# Operator: Our next question is from Vivek Arya with Bank of America Securities.
# Vivek Arya: Lisa, I just wanted to go back to the supply question and the $4 billion outlook for this year. I think at some point, there was a suggestion that the $4 billion number, right, that there are still supply constraints. But I think at a different point, you said that you have supply visibility significantly beyond that.
#  Given that we are almost at the middle of the year, I would have thought that you would have much better visibility about the back half. So is the $4 billion number a supply-constrained number, or is it a demand-constrained number? Or alternatively, if you could give us some sense of what the exit rate of your GPU sales could be. I think on the last call, $1.5 billion was suggested. Could it be a lot more than that in terms of your exit rate of MI for this year?
# Lisa Su: Yes. Vivek, let me try to make sure that we answered this question clearly. From a full year standpoint, our $4 billion number is not supply capped -- I'm sorry, yes, it's not supply capped. It is -- we do have supply capability above that. It is more back half weighted. So if you're looking at sort of the near term, I would say, for example, in the second quarter, we do have more demand than we have supply right now, and we're continuing to work on pulling in some of that supply.
#  By the way, I think this is an overall industry issue. This is not at all related to AMD. I think overall, AI demand has exceeded anyone's expectations in 2024. So you've heard it from the memory guys. You've heard it from the foundry guys. We're all ramping capacity as we go through the year.
#  And as it relates to visibility, we do have good visibility into what's happening. As I said, we have great customer engagements that are going forward. My goal is to make sure that we pass all of the milestones as we're ramping products. And as we pass those milestones, we put that into the overall full year guidance for AI.
#  But in terms of how customer progression, things are going, they're actually going quite well. And we continue to bring new customers on, and we continue to expand workloads with our current customers. And so hopefully, that clarifies the question, Vivek.
# Vivek Arya: Maybe one, not on MI, but maybe on the Embedded business. I think you sound a bit more measured about Q2 and the second half rebound, which is similar to what we have heard from a lot of the auto industrial peers. But where are you in the inventory clearing cycle? And if Embedded has a somewhat more measured rebound in the back half, what implication does that have on gross margin expansion? Can we continue to expect, I don't know, 100 basis points a quarter in terms of gross margin expansion because of the Data Center mix? Or just any puts and takes of Embedded and then what it means for gross margins in the back half?
# Jean Hu: Vivek, thank you for the question. I think the Embedded business declined a little bit more than expected, really due to the weaker demand in some of the markets, very specifically, communication has been weak. And some pockets of industrial and automotive, as you mentioned, it's actually quite consistent with the peers.
#  Second half, we do think the first half is the bottom of Embedded business and will start to see gradual recovery in the second half. And going back to your gross margin question is, when you look at our gross margin expansion in both Q1 and the guide at Q2, the primary driver is the strong performance on the Data Center side. The Data Center will continue to ramp in second half. I think that will continue to be the major driver of gross margin expansion in second half. Of course, if Embedded is doing better, we'll have a more tailwind in the second half.
# Operator: Our next question is from Timothy Arcuri with UBS. --- Chunk_id: 8
# 2) Content: Operating expenses were $1.7 billion, an increase of 10% year-over-year, as we continued investing aggressively in R&D and marketing activities to address the significant AI growth opportunities ahead of us. Operating income was $1.1 billion, representing a 21% operating margin. Taxes, interest expense and other was $120 million. For the fourth quarter of 2024, diluted earnings per share was $0.62, an increase of 3% year-over-year.
#  Now turning to our Reportable segment, starting with the Data Center. Data Center delivered record quarterly segment revenue of $2.3 billion, up 80%, a $1 billion increase year-over-year. Data Center accounted for more than 40% of total revenue, primarily led by the ramp of AMD Instinct GPUs from both cloud and enterprise customers and a strong double-digit percentage growth in our server process revenue as a result of growth across our sample products.
#  On a sequential basis, revenue increased 2%, driven by the ramp of our AMD Instinct GPUs, partially offset by seasonal decline in server CPU sales. Data Center segment operating income was $541 million or 23% of revenue compared to $148 million or 11% a year ago. Operating income was up 266% year-over-year due to operating leverage even as we significantly increased our investment in R&D.
#  Client segment revenue was $1.4 billion, up 85% year-over-year, driven primarily by Ryzen 8000 series processors. On a sequential basis, Client revenue declined 6%. Client segment operating income was $86 million or 6% of revenue compared to an operating loss of $172 million a year ago, driven by higher revenue.
#  Gaming segment revenue was $922 million, down 48% year-over-year and down 33% sequentially due to a decrease in semi customer and Radeon GPU sales. Gaming segment operating income was $151 million or 16% of revenue compared to $314 million or 18% a year ago.
#  Embedded segment revenue was $846 million, down 46% year-over-year and 20% sequentially as customers continue to manage their inventory levels. Embedded segment operating income was $342 million or 41% of revenue compared to $798 million or 51% a year ago.
#  Turning to the balance sheet and cash flow. During the quarter, we generated $521 million in cash from operations, and free cash flow was $379 million. Inventory increased sequentially by $301 million to $4.7 billion, primarily to support the continued ramp of data center and client products in advanced process node.
#  At the end of the quarter, cash, cash equivalent and short-term investment was $6 billion. As a reminder, we have $750 million of debt maturing this June. Given our ample liquidity, we plan to retire that utilizing existing cash.
#  Now turning to our second quarter 2024 outlook. We expect revenue to be approximately $5.7 billion, plus or minus $300 million. Sequentially, we expect Data Center segment revenue to increase by double-digit percentage, primarily driven by the Data Center GPU ramp; client segment revenue to increase; embedded segment revenue to be flat; and in the Gaming segment, based on current demand signals, revenue to decline by significant double-digit percentage.
#  Year-over-year, we expect our Data Center and Client segment revenue to be up significantly, driven by the strength of our product portfolio; the Embedded and the Gaming segment revenue to decline by a significant double-digit percentage. In addition, we expect second quarter non-GAAP gross margin to be approximately 53%. Non-GAAP operating expenses to be approximately $1.8 billion. Non-GAAP effective tax rate to be 13% and the diluted share count is expected to be approximately 1.64 billion shares.
#  In closing, we started the year strong. We made significant progress on our strategic priorities, delivering year-over-year revenue growth in our Data Center and the Client segment and expanded the gross margin. Looking ahead, we believe the investments we are making will position us very well to address the large AI opportunities ahead.
#  With that, I'll turn it back to Mitch for the Q&A session.
# Mitchell Haws: Thank you, Jean. Paul, we're happy to poll the audience for questions.
# Operator: [Operator Instructions] Our first question is from Toshiya Hari with Goldman Sachs. --- Chunk_id: 4
# 3) Content: Operator: Our last question is from Harsh Kumar with Piper Sandler.
# Harsh Kumar: Lisa, I had two. One is for you and one perhaps for Jean. So we recently hosted a very large custom GPU company for a call. And they talked about kind of mega data centers coming up in the near to midterm, talking about nodes potentially in the 100,000-plus range and maybe up to 1 million. So as we look out at these kinds of data centers, from an architectural standpoint, it's not a situation where winner takes all, where if somebody gets in, they kind of get all the sockets?
#  Or will there reliance where your chip perhaps or your board can be placed right next to somebody else's board maybe on a separate line? Just help us understand how something like that would play out if there's a  chance for more than 1 competitor to play in such a large data center?
# Lisa Su: Yes. So I'll talk maybe a little bit more at the strategic level. I think as we look at sort of how AI shapes up over the next few years, there are customers who would be looking at very large training environments and perhaps that's what you're talking about. I think our view of that is, number one, we view that as a very attractive area for AMD. It's an area where we believe we have the technology to be very competitive there.
#  And I think the desire would be to have optionality in terms of how you build those out. So obviously, a lot has to happen between here and there. But I think your overarching question of. Is it winner takes all? I don't think so. That being the case, we believe that AMD is very well positioned to play in those, let's call it, of very large scale systems.
# Harsh Kumar: That's wonderful. And then maybe a quick one for Jean. So Jean, I put everything into the model that you talked about for June, I get about more or less a $400 million rise in the June quarter over March. You mentioned that both MI300 and EPYC will grow. Curious if you could help us think about the relative sizing of those 2 segments within the growth? I'm getting -- the point I'm trying to make is I'm getting roughly about a $900 million number for MI300 for June. Is that -- am I in the ballpark? Or am I way off here?
# Jean Hu: Harsh, we're not going to guide a specific segment below the segment revenue. I think the most important thing is that we did say Data Center is going to grow double digit sequentially. I will leave it over there. Subsegment, there are a lot of details.
# Operator: There are no further questions at this time. I'd like to hand the floor back over to management for any closing comments.
# Mitchell Haws: Great. That concludes today's call. Thanks to all of you for joining us today.
# Lisa Su: Thanks.
# Operator: This concludes today's conference. You may disconnect your lines at this time. Thank you for your participation. --- Chunk_id: 12
# 4) Content: Operator: Greetings, and welcome to the AMD First Quarter 2024 Conference Call. [Operator Instructions] As a reminder, this conference is being recorded.
#  It is now my pleasure to introduce your host, Mitch Haws, Vice President, Investor Relations. Thank you. Mitch, you may begin.
# Mitchell Haws: Thank you, and welcome to AMD's First Quarter 2024 Financial Results Conference Call. By now, you should have had the opportunity to review a copy of our earnings press release and the accompanying slides. If you have not had the chance to review these materials, they can be found on the Investor Relations page of amd.com. We will refer primarily to non-GAAP financial measures during today's call, and the full non-GAAP to GAAP reconciliations are available in today's press release and the slides posted on our website.
#  Participants on today's call are Dr. Lisa Su, our Chair and Chief Executive Officer; and Jean Hu, our Executive Vice President, Chief Financial Officer and Treasurer. This is a live call and will be replayed via webcast on our website. Before we begin, I would like to note that Mark Papermaster, Executive Vice President and Chief Technology Officer, will attend the TD Cowen Technology, Media and Telecom Conference on May 29; and Jean Hu, Executive Vice President, Chief Financial Officer and Treasurer, will attend the JPMorgan Global Media and Communications Conference on Tuesday, May 21; the Bank of America Global Technology Conference on Wednesday, June 5; and the Jefferies Nasdaq Investor Conference on Tuesday, June 11.
#  Today's discussion contains forward-looking statements based on current beliefs, assumptions and expectations, speak only as of today and as such, involve risks and uncertainties that could cause actual results to differ materially from our current expectations. Please refer to the cautionary statement in our press release for more information on the factors that could cause actual results to differ materially.
#  With that, I will hand the call over to Lisa.
# Lisa Su: Thanks, Mitch, and good afternoon to all those listening today. This is an incredibly exciting time for the industry as the widespread deployment of AI is driving demand for significantly more compute across a broad range of markets. Under this backdrop, we are executing very well as we ramp our data center business and enable AI capabilities across our product portfolio.
#  Looking at the first quarter, revenue increased to $5.5 billion. We expanded gross margin by more than 2 percentage points and increased profitability as Data Center and Client segment sales each grew by more than 80% year-over-year.
#  Data Center segment revenue grew 80% year-over-year and 2% sequentially to a record $2.3 billion. The substantial year-over-year growth was driven by the strong ramp of AMD Instinct MI300X GPU shipments and a double-digit percentage increase in server CPU sales. We believe we gained server CPU revenue share in the seasonally down first quarter, led by growth in enterprise adoption and expanded cloud deployments.
#  In cloud, while the overall demand environment remain mixed, hyperscalers continued adopting fourth-gen EPYC processors to power more of their internal workloads and public instances. There are now nearly 900 AMD-powered public instances available globally as Amazon, Microsoft and Google all increased their fourth-gen EPYC processor offerings with new instances and regional deployments.
#  In the enterprise, we have seen signs of improving demand as CIOs need to add more general purpose and AI compute capacity while maintaining the physical footprint and power needs of their current infrastructure. This scenario aligns perfectly with the value proposition of our EPYC processors.
#  Given our high core count and energy efficiency, we can deliver the same amount of compute with 45% fewer servers compared to the competition, cutting initial CapEx by up to half and lowering annual OpEx by more than 40%. As a result, enterprise adoption of EPYC CPUs is accelerating, highlighted by deployments with large enterprises, including American Airlines, DBS, Emirates Bank, Shell and STMicro.
#  We're also building momentum with AMD-powered solutions powering the most popular ERP and database applications. As one example of the latest generation of Oracle Exadata, the leading database solution used by 76 of the Fortune 100, is now powered exclusively by fourth-gen EPYC processors. Looking ahead, we're very excited about our next-gen Turin family of EPYC processors featuring our Zen 5 core. We're widely sampling Turin and the silicon is looking great. --- Chunk_id: 1
# 5) Content: Operator: Our next question is from Timothy Arcuri with UBS.
# Timothy Arcuri: I also wanted to ask about your data center GPU road map. The customers that we talk to say that they're engaged, not just because of MI300, but really because of what's coming. And it seems like there's a big demand shift to rack scale systems that try to optimize performance per square foot given some of the data center and power constraints. So can you just talk about how important systems are going to be in your road map? And do you have all the pieces you need as the market shifts to rack scale systems?
# Lisa Su: Yes, sure, Timothy. Thanks for the question. For sure, look, our customers are engaged in the multigenerational conversation. So we're definitely going out over the next couple of years. And as it relates to the overall system integration, it is quite important. It is something that we're working very closely with our customers and partners on. That's a significant investment in networking, working with a number of networking partners as well to make sure that the scale-out capability is there.
#  And to your question of do we have the pieces? We do absolutely have the pieces, I think the work that we've always done with our Infinity Fabric as well as with our Pensando acquisition that's brought in a lot of networking expertise. And then we're working across the networking ecosystem with key partners like Broadcom and Cisco and Arista, who are with us at our AI data center event in December.
#  So our work right now in future generations is not just specifying a GPU, it is specifying, let's call it, full system reference designs. And that's something that will be quite important going forward.
# Timothy Arcuri: And then just as a quick follow-up. I know this year it looks like it's going to be pretty back-half loaded in your server CPU business, just like it was last year. I know you kind of held our hands at about this time last year sort of on what the full year could look like and how back-end loaded it could be.
#  So I kind of wonder, could you give us some milestones in terms of how much server CPU could grow this year, how back-end loaded it could be? Is it like up 30% this year for your server CPU business year-over-year? Is that a reasonable bogey? I just wonder if you can kind of give us any guidance on that piece of the business?
# Lisa Su: Yes. I mean, I think, Tim, I think the best way to say it is our Data Center segment is on a very, very strong ramp as we go through the back half of the year. Server CPUs, certainly, Data Center GPUs, for sure. So I don't know that we're going to get into specifics, but I could say, in general, you should expect overall at the segment level to be very strong double digits.
# Operator: Our next question is from Joe Moore with Morgan Stanley.
# Joseph Moore: I wonder if you could address the profitability of MI300. I know you said a couple of quarters ago that it would eventually be above corporate average, but it would take you a few quarters to get there. Can you talk about where you are in that?
# Jean Hu: Yes. Thank you, Joe. Our team has done an incredible job to ramp MI300. As you probably know, it's a very complex product, and we are still at the first year of the ramp, both from yield, the testing time and the process improvement, those things are still ongoing. We do think over time, the gross margin should be accretive to corporate average.
# Joseph Moore: Great. And then as a separate follow-up. On the Turin transition on server, I know when you had transitioned in generally, you said it could take a little while, that there were significant platform shifts and things like that. Turin seems to be much more kind of ecosystem compatible. How quickly do you think you might see that product ramp within our server portfolio?
# Lisa Su: Yes. Joe, I think from what we see, look, think Turin is the same platform so that does make it an easier ramp. I do think that Genoa and Turin will coexist for some amount of time because customers are deciding when they're going to bring out their new platforms. We expect Turin to give us access to a broader set of workloads. So our SAM actually expands with Turin, both in enterprise and cloud. And from our experience, I think you'll see a faster transition than, for example, when we went from Milan to Genoa. --- Chunk_id: 9
# 6) Content: Operator: Our next question is from Stacy Rasgon with Bernstein Research.
# Stacy Rasgon: For my first one, I wanted to address the MI300 ramp into Q2. So you said you've done $1 billion, give or take, in cumulative sales, which puts it at maybe, I don't know, maybe $600 million in Q1. You're guiding total revenues up about $225 million into Q2, but you've got Client up, you've got traditional Data Center up, you've got Embedded flat. Gaming is going to be down, but I'd hazard a guess that the client and traditional Data Center offset it, if not more. Does the MI300 ramp into Q2? Is it more or less than the total corporate ramp that you've got built into guidance right now that you're expecting?
# Jean Hu: Stacy, thanks for the question. You always ask a math question. So I think, in general, it is more. The Data Center GPU ramp, it will be more than the overall company's $200-some million ramp.
# Stacy Rasgon: Okay. So that means Gaming must be down like a lot, right, if client [indiscernible]
# Jean Hu: Yes, yes, you're right. Gaming is down similar zip code like  Q1.
# Stacy Rasgon: Got it. Got it. That's helpful.
# Jean Hu: So maybe -- yes, maybe let me give you some color about the Gaming business, right? If you look at the Gaming, the demand has been quite weak, that's quite very well-known and also their inventory level. So based on the visibility we have, the first half, both Q1, Q2, we guided down sequentially more than 30%. We actually think the second half will be lower than first half.
#  That's basically how we're looking at this year for the Gaming business. And at the same time, Gaming's gross margin is lower than our company average. So overall, will help the mix on the gross margin side. That's just some color on the Gaming side. But you're right, Q2 Gaming is down a lot.
# Stacy Rasgon: Got it. That's helpful. For my second question, I wanted to look at the near-term Data Center profitability. So operating profit was down 19% sequentially on 2% revenue growth. Is that just the margins of the GPUs filtering in relative to the CPUs? And I know you said GPUs would eventually be above corporate average. Are they below the CPU average? I mean they clearly are, I guess, in the near term, but are they going to stay that way?
# Jean Hu: Yes. I think you're right. It's -- the GPU gross margin right now is below the Data Center gross margin level, I think there are 2 reasons. Actually, the major reason is we actually increased the investment quite significantly to, as Lisa mentioned, to expand and accelerating our road map in the AI side. That's one of the major drivers for the operating income coming down slightly.
#  On the gross margin side, going back to your question, we said in the past, and we continue to believe the case is, Data Center GPU gross margin over time will be accretive to corporate average. But it will take a while to get to the Server level for gross margin.
# Operator: Our next question is from Harlan Sur with JPMorgan.
# Harlan Sur: On your Data Center GPU segment and the faster time to production shipments, given you just upped your full year GPU outlook, how much of it is faster bring up of your customers' frameworks driven by your latest ROCm software platform and maybe stronger collaboration with your customers' engineers just to get them to call faster? And how much of it is just a more aggressive build-out plan by customers versus their prior expectations given what appears to be a pretty strong urgency for them to move forward with their important AI initiatives?
# Lisa Su: Yes. Harlan, thank you for the question. What it really is, is both us and our customers feeling confident in broadening the ramp? Because if you think about it, first of all, the ROCm stock has done really well. And the work that we're doing is hand in hand with our customers to optimize their key models. And it was important to get sort of verification and validation that everything would run well, and we've now passed some important milestones in that area. . --- Chunk_id: 10
# 7) Content: In the cloud, the significant performance and efficiency increases of Turin position us well to capture an even larger share of both first and third-party workloads. In addition, there are 30% more Turin platforms in development from our server partners compared to fourth-gen EPYC platforms, increasing our enterprise SAM with new solutions optimized for additional workloads. Turin remains on track to launch later this year.
#  Turning to our broader Data Center portfolio. We delivered our second straight quarter of record data center GPU revenue as MI300 became the fastest-ramping product in AMD history, passing $1 billion in total sales in less than 2 quarters. In cloud, MI300x production deployments expanded at Microsoft, Meta and Oracle to power Generative AI training and inferencing for both internal workloads and a broad set of public offerings.
#  For the enterprise, we're working very closely with Dell, HPE, Lenovo, Super Micro and others as multiple MI300X platforms enter volume production this quarter. In addition, we have more than 100 enterprise and AI customers actively developing or OpenAI MI300X.
#  On the AI software front, we made excellent progress adding upstream support for AMD hardware in the open AI Triton compiler, making it even easier to develop highly performant AI software for AMD platforms.
#  We also released a major update to our ROCm software stack that expand support for open source libraries, including vLLM, and frameworks, including JAKs, adds new features like video decode and significantly increases generative AI performance by integrating advanced attention algorithm support for sparsity and FPA.
#  Our partners are seeing very strong performance in their AI workloads. As we jointly optimize for their models, MI300X GPUs are delivering leadership inferencing performance and substantial TCO advantages compared to H100. For instance, several of our partners are seeing significant increases in tokens per second when running their flagship LLMs on MI300x compared to H100.
#  We're also continuing to enable the broad ecosystem required to power the next generation of AI systems, including as a founding member of the Ultra Ethernet Consortium, working to optimize the widely adopted Ethernet protocol to run AI workloads at data center scale.
#  MI300 demand continues to strengthen. And based on our expanding customer engagements, we now expect data center GPU revenue to exceed $4 billion in 2024, up from the $3.5 billion we guided in January. Longer term, we are increasingly working closer with our cloud and enterprise customers as we expand and accelerate our AI hardware and software road maps and grow our data center GPU footprint.
#  Turning to our Client segment. Revenue was $1.4 billion, an increase of 85% year-over-year, driven by strong demand for our latest-generation Ryzen mobile and desktop processors with OEMs and in the channel. Client segment revenue declined 6% sequentially.
#  We saw strong demand for our latest-generation Ryzen processors in the first quarter. Ryzen desktop CPU sales grew by a strong double-digit percentage year-over-year, and Ryzen mobile CPU sales nearly doubled year-over-year as new Ryzen 8040 notebook designs from Acer, Asus, HP, Lenovo and others ramped.
#  We expanded our portfolio of leadership enterprise PC offerings with the launch of our Ryzen Pro 8000 processors earlier this month. Ryzen Pro 8040 mobile CPUs delivered industry-leading performance in battery life for commercial notebooks. And our Ryzen Pro 8000 series desktop CPUs are the first processor to offer dedicated, on-chip AI accelerators in commercial desktop PCs.
#  We see clear opportunities to gain additional commercial PC share based on the performance and efficiency advantages of our Ryzen Pro portfolio and an expanded set of AMD-powered commercial PCs from our OEM partners. Looking forward, we believe the market is on track to return to annual growth in 2024, driven by the start of an enterprise refresh cycle and AI PC adoption.
#  We see AI as the biggest inflection point in PC since the Internet, with the ability to deliver unprecedented productivity and usability gains. We're working very closely with Microsoft and a broad ecosystem of partners to enable the next generation of AI experiences, powered by Ryzen processors, with more than 150 ISVs on track to be developing for AMD AI PCs by the end of the year.
#  We will also take the next major step in our AI PC road map later this year with the launch of our next-generation Ryzen mobile processors codenamed Strix. Customer interest in Strix is very high based on the significant performance and energy efficiency uplifts we are delivering. --- Chunk_id: 2
# 8) Content: Design win momentum for premium notebooks is outpacing prior generations as Strix enables next-generation AI experiences in laptops that are thinner, lighter and faster than ever before. We're excited about the growth opportunities for the PC market. And based on the strength of our Ryzen CPU portfolio, we expect to grow revenue share this year.
#  Now turning to our Gaming segment. Revenue declined 48% year-over-year and 33% sequentially to $922 million. First quarter semi-custom SoC sales declined in line with our projections as we are now in the fifth year of the console cycle. In Gaming Graphics, revenue declined year-over-year and sequentially. We expanded our Radeon 7000 Series family with the global launch of our Radeon RX 7900 GRE and also introduced our driver-based AMD fluid motion frames technology that can provide large performance increases in thousands of games.
#  Turning to our Embedded segment. Revenue decreased 46% year-over-year and 20% sequentially to $846 million as customers remain focused on normalizing their inventory levels. We launched our Spartan UltraScale+ FPGA family with high I/O counts, power efficiency and state-of-the-art security features, and we're seeing a strong pipeline of growth for our cost-optimized embedded portfolio across multiple markets.
#  Given the current embedded market conditions, we're now expecting second quarter embedded segment revenue to be flat sequentially, with a gradual recovery in the second half of the year. Longer term, we see AI at the edge as a large growth opportunity that will drive increased demand for compute across a wide range of devices. To address this demand, we announced our second generation of Versal adaptive SoCs that deliver a 3x increase in AI tops per watt and a 10x greater scaler compute performance compared to our prior generation of industry-leading adaptive SoCs.
#  Versal Gen 2 adaptive SoCs are the only solution that combine multiple compute engines to handle AI preprocessing, inferencing and post processing on a single chip, enabling customers to rapidly add highly performant and efficient AI capabilities to a broad range of products. We were pleased to be joined at our launch by Subaru, who announced they adopted Versal AI Edge series Gen 2 devices to power the next generation of their EyeSight ADAS system.
#  Embedded Design win momentum remains very strong as customers adopt our full portfolio of FPGAs, CPUs, GPUs and adaptive SoCs to address a larger portion of their compute needs. In summary, we executed well in the first quarter, setting us up to deliver strong annual revenue growth and expanded gross margin, driven by growing adoption of our Instinct, EPYC and Ryzen product portfolios.
#  Our priorities for 2024 are very clear: accelerate our Data Center growth by ramping Instinct GPU production and gaining share with our EPYC processors; launch our next-generation Zen 5 PC and server processors that extend our leadership performance; and expand our adaptive computing portfolio with differentiated solutions.
#  Looking further ahead, AI represents an unprecedented opportunity for AMD. While there has been significant growth in AI infrastructure build-outs, we are still in the very early stages of what we believe is going to be a period of sustained growth, driven by an insatiable demand for both high-performance AI and general purpose compute.
#  We have expanded our investments across the company to capture this large growth opportunity, from rapidly expanding our AI software stack to accelerating our AI hardware road maps, increasing our go-to-market activities and partnering closely with the largest AI companies to co-optimize solutions for their most important workloads. We are very excited about the trajectory of the business and the significant growth opportunities ahead.
#  Now I'd like to turn the call over to Jean to provide some additional color on our first quarter results. Jean?
# Jean Hu: Thank you, Lisa, and good afternoon, everyone. I'll start with a review of our financial results and then provide our current outlook for the second quarter of fiscal 2024. We delivered strong year-over-year revenue growth in our Data Center and Client segments in the fourth quarter and grew 230 basis points of gross margin expansion. For the first quarter of 2024, revenue was $5.5 billion, up 2% year-over-year as revenue growth in the Data Center and the Client segment was partially offset by lower revenue in our Gaming and Embedded segment.
#  Revenue declined 11% sequentially as higher Data Center revenue resulting from the ramp of our AMD Instinct GPUs was offset by lower Gaming and Embedded segment revenues. Gross margin was 52%, up 230 basis points year-over-year, driven by higher revenue contribution from the Data Center and Client segment, partially offset by lower Embedded and Gaming segment revenue contribution. --- Chunk_id: 3
# 9) Content: Mitchell Haws: Thank you, Jean. Paul, we're happy to poll the audience for questions.
# Operator: [Operator Instructions] Our first question is from Toshiya Hari with Goldman Sachs.
# Toshiya Hari: Lisa, my first question is on the MI300. You're taking up the full year outlook from $3.5 billion to $4 billion. I'm curious what's driving that incremental $500 million in revenue? Is it new customers? Is it additional bookings from existing customers? Is it more cloud? Is it more enterprise? If you can sort of provide color there, that would be helpful.
#  And then on the supply side, there's been headlines or chatter that CoWoS and/or HBM could be a pretty severe constraining factor for you guys. If you can speak to how you're handling the supply side of the equation, that would be helpful, too. And then I have a quick follow-up.
# Lisa Su: Great. Thank you, Toshiya, for the question. Look, the MI300 ramp is going really well. If we look at just what's happened over the last 90 days, we've been working very closely with our customers to qualify MI300 in their production data centers, both from a hardware standpoint, software standpoint. So far, things are going quite well.
#  And what we see now is just greater visibility to both current customers as well as new customers committing to MI300. So that gives us the confidence to go from $3.5 billion to $4 billion. And I view this as very much -- it's a very dynamic market, and there are lots of customers. We said on the -- in the prepared remarks that we have over 100 customers that we're engaged with in both development as well as deployment. So overall, the ramp is going really well.
#  As it relates to the supply chain, actually, I would say, I'm very pleased with how supply has ramped. It is absolutely the fastest product ramp that we have done. It's a very complex product, chiplets, CoWoS, 3D integration, HBM. And so far, it's gone extremely well. We've gotten great support from our partners. And so I would say, even in the quarter that we just finished, we actually did a little bit better than expected when we first started the quarter.
#  I think Q2 will be another significant ramp. And we're going to ramp supply every quarter this year. So I think the supply chain is going well. We are tight on supply. So there's no question in the near term that if we had more supply, we have demand for that product, and we're going to continue to work on those elements as we go through the year. But I think both on the demand side and the supply side, I'm very pleased with how the ramp is going.
# Toshiya Hari: And then as my follow-up, I was hoping you could speak to your Data Center GPU road map beyond the MI300. The other concern that we hear is your nearest competitor has been pretty transparent with their road map, and that extends into '25 and oftentimes '26. So -- and maybe this isn't the right venue for you to give too much, but beyond the MI300, how should we think about your road map and your ability to compete in Data Center?
# Lisa Su: Yes, sure. So look, Toshiya, when we start with the road map, I mean, we always think about it as a multiyear, multigenerational road map. So we have the follow-ons to MI300 as well as the next, next generations well in development. I think what is true is we're getting much closer to our top AI customers. They're actually giving us significant feedback on the road map and what we need to meet their needs.
#  Our chiplet architecture is actually very flexible. And so that allows us to actually make changes to the road map as necessary. So we're very confident in our ability to continue to be very competitive. Frankly, I think we're going to get more competitive. Right now, I think MI300x is in a sweet spot for inference, very, very strong inference performance.
#  I see as we bring in additional products later this year into 2025, that, that will continue to be a strong spot for us. And then we're also enhancing our training performance and our software road map to go along with it. So more details to come in the coming months, but we have a strong road map that goes through the next couple of years, and it is informed by just a lot of learning in working with our top customers. --- Chunk_id: 5
# 10) Content: From my view, there are several aspects of it. First of all, we have great relationships with all of sort of the top AI companies. And the idea there is we want to innovate together. When you look at these large language models and everything that you need for training and inferencing there, although -- there will be many solutions. I don't think there's just one solution that will fit all. The GPU is still the preferred architecture, especially as the algorithms and the models are continuing to evolve over time. And that favors our architecture and also our ability to really optimize CPU with GPU.
#  So from my standpoint, I think we're very happy with the partnerships that we have. I think this is a huge opportunity for all of us to really innovate together. And we see that there's a very strong commitment to working together over multiple years going forward. And that's, I think, a testament to some of the work that we've done in the past, and that very much is what happened with the EPYC road map as well.
# Matthew Ramsay: Lisa, as my follow-up, a little bit shorter term. And I guess, having followed the company super closely for a long time, I think there's been -- there's always been noise in the system from whether the stock price is $2 a share or $200. There's been kind of always consistent noise one way or the other, but the last 1.5 months has been extreme in that sense.
#  And so I wanted to just -- I got random reports by inbox about changes in demand from some of your MI300 customers or planned demand for consuming your product. I think you answered earlier about the supply situation and how you're working with your partners there. But has there been any change from the customers that you're in ramp with now or that you soon will be of what their intention is for demand? Or in fact, has that maybe strengthened rather than gone down in recent periods because I keep getting questions about it?
# Lisa Su: Sure, Matt. Look, I think I might have said it earlier, but maybe I'll repeat it again. I think the demand side is actually really strong. And what we see with our customers and what we are tracking very closely is customers moving from, let's call it, initial POCs to pilots to full-scale production to deployment across multiple workloads. And we're moving through that sequence very well. I feel very good about the deployments and ramps that we have ongoing right now.
#  And I also feel very good about new customers who are sort of earlier on in that process. So from a demand standpoint, we continue to build backlog as well as build engagements going forward. And similarly, on the supply standpoint, we're continuing to build supply momentum. But from a speed of ramp standpoint, I'm actually really pleased with the progress.
# Operator: Our next question is from Aaron Rakers with Wells Fargo.
# Aaron Rakers: I apologize if I missed this earlier, but I know last quarter, you talked about having a -- securing enough capacity to support significant upside to the ramp of the MI300. I know that you upped your guide now to $4 billion. I'm curious how you would characterize the supply relative to that context offered last quarter as we think about that new kind of target for? Would you characterize it as still having supply capacity upside potential?
# Lisa Su: Yes, Aaron. So we've said before that our goal is to ensure that we have supply that exceeds the current guidance, and that is true. So as we've upped our guidance from $3.5 billion to $4 billion, we still -- we have supply visibility significantly beyond that.
# Aaron Rakers: Yes. Okay. And then as a quick follow-up, going back to an earlier question on server demand, more traditional server. As you see the ramp of maybe share opportunities in more traditional enterprise, I'm curious how you would characterize the growth that you expect to see a more traditional server CPU market as we move through '24 or even longer term, how you'd characterize that growth trend?
# Lisa Su: Yes. I think, Aaron, what I would say is there are -- the need for refresh of, let's call it, older equipment is certainly there. So we see a refresh cycle coming. We also see AI head nodes as another place where we see growth in, let's call it, the more traditional SSD market. Our sweet spot is really in the highest performance, sort of high core count, energy efficiency space, and that is playing out well. --- Chunk_id: 7

# %% [markdown]
# ### Testing

# %% [markdown]
# #### Test - 1

# %%
test_query_1 = "what is the essay \"Founder Mode\" about?"
res_proposition = retriever_propositions.invoke(test_query_1)
res_larger = retriever_larger.invoke(test_query_1)
# Out:
# OllamaEmbeddings:   0%|          | 0/1 [00:00<?, ?it/s]
# OllamaEmbeddings: 100%|██████████| 1/1 [00:00<00:00, 18.55it/s]
# OllamaEmbeddings: 100%|██████████| 1/1 [00:00<00:00, 35.04it/s]

# %%
for i, r in enumerate(res_proposition):
    print(f"{i+1}) Content: {r.page_content} --- Chunk_id: {r.metadata['chunk_id']}")
# Out:
# 1) Content: Founder Mode is an emerging paradigm. --- Chunk_id: 1
# 2) Content: Founder Mode is an emerging paradigm that is not yet fully understood or documented. --- Chunk_id: 2
# 3) Content: Founder Mode is not yet fully understood or documented. --- Chunk_id: 1
# 4) Content: Founder Mode contrasts with the conventional 'manager mode'. --- Chunk_id: 1

# %%
for i, r in enumerate(res_larger):
    print(f"{i+1}) Content: {r.page_content} --- Chunk_id: {r.metadata['chunk_id']}")
# Out:
# 1) Content: Paul Graham's essay "Founder Mode," published in September 2024, challenges conventional wisdom about scaling startups, arguing that founders should maintain their unique management style rather than adopting traditional corporate practices as their companies grow.
# Conventional Wisdom vs. Founder Mode
# The essay argues that the traditional advice given to growing companies—hiring good people and giving them autonomy—often fails when applied to startups.
# This approach, suitable for established companies, can be detrimental to startups where the founder's vision and direct involvement are crucial. "Founder Mode" is presented as an emerging paradigm that is not yet fully understood or documented, contrasting with the conventional "manager mode" often advised by business schools and professional managers.
# Unique Founder Abilities
# Founders possess unique insights and abilities that professional managers do not, primarily because they have a deep understanding of their company's vision and culture. --- Chunk_id: 1
# 2) Content: Unique Founder Abilities
# Founders possess unique insights and abilities that professional managers do not, primarily because they have a deep understanding of their company's vision and culture.
# Graham suggests that founders should leverage these strengths rather than conform to traditional managerial practices. "Founder Mode" is an emerging paradigm that is not yet fully understood or documented, with Graham hoping that over time, it will become as well-understood as the traditional manager mode, allowing founders to maintain their unique approach even as their companies scale.
# Challenges of Scaling Startups
# As startups grow, there is a common belief that they must transition to a more structured managerial approach. However, many founders have found this transition problematic, as it often leads to a loss of the innovative and agile spirit that drove the startup's initial success. --- Chunk_id: 2
# 3) Content: Brian Chesky, co-founder of Airbnb, shared his experience of being advised to run the company in a traditional managerial style, which led to poor outcomes. He eventually found success by adopting a different approach, influenced by how Steve Jobs managed Apple.
# Steve Jobs' Management Style
# Steve Jobs' management approach at Apple served as inspiration for Brian Chesky's "Founder Mode" at Airbnb. One notable practice was Jobs' annual retreat for the 100 most important people at Apple, regardless of their position on the organizational chart
# . This unconventional method allowed Jobs to maintain a startup-like environment even as Apple grew, fostering innovation and direct communication across hierarchical levels. Such practices emphasize the importance of founders staying deeply involved in their companies' operations, challenging the traditional notion of delegating responsibilities to professional managers as companies scale. --- Chunk_id: 3

# %% [markdown]
# #### Test - 2

# %%
test_query_2 = "who is the co-founder of Airbnb?"
res_proposition = retriever_propositions.invoke(test_query_2)
res_larger = retriever_larger.invoke(test_query_2)
# Out:
# OllamaEmbeddings: 100%|██████████| 1/1 [00:00<00:00, 17.47it/s]
# OllamaEmbeddings: 100%|██████████| 1/1 [00:00<00:00, 62.75it/s]

# %%
for i, r in enumerate(res_proposition):
    print(f"{i+1}) Content: {r.page_content} --- Chunk_id: {r.metadata['chunk_id']}")
# Out:
# 1) Content: Brian Chesky is a co-founder of Airbnb. --- Chunk_id: 3
# 2) Content: Brian Chesky adopted a different approach to running Airbnb. --- Chunk_id: 3
# 3) Content: Brian Chesky was advised to run Airbnb in a traditional managerial style. --- Chunk_id: 3
# 4) Content: Running Airbnb in a traditional managerial style led to poor outcomes. --- Chunk_id: 3

# %%
for i, r in enumerate(res_larger):
    print(f"{i+1}) Content: {r.page_content} --- Chunk_id: {r.metadata['chunk_id']}")
# Out:
# 1) Content: Brian Chesky, co-founder of Airbnb, shared his experience of being advised to run the company in a traditional managerial style, which led to poor outcomes. He eventually found success by adopting a different approach, influenced by how Steve Jobs managed Apple.
# Steve Jobs' Management Style
# Steve Jobs' management approach at Apple served as inspiration for Brian Chesky's "Founder Mode" at Airbnb. One notable practice was Jobs' annual retreat for the 100 most important people at Apple, regardless of their position on the organizational chart
# . This unconventional method allowed Jobs to maintain a startup-like environment even as Apple grew, fostering innovation and direct communication across hierarchical levels. Such practices emphasize the importance of founders staying deeply involved in their companies' operations, challenging the traditional notion of delegating responsibilities to professional managers as companies scale. --- Chunk_id: 3
# 2) Content: Paul Graham's essay "Founder Mode," published in September 2024, challenges conventional wisdom about scaling startups, arguing that founders should maintain their unique management style rather than adopting traditional corporate practices as their companies grow.
# Conventional Wisdom vs. Founder Mode
# The essay argues that the traditional advice given to growing companies—hiring good people and giving them autonomy—often fails when applied to startups.
# This approach, suitable for established companies, can be detrimental to startups where the founder's vision and direct involvement are crucial. "Founder Mode" is presented as an emerging paradigm that is not yet fully understood or documented, contrasting with the conventional "manager mode" often advised by business schools and professional managers.
# Unique Founder Abilities
# Founders possess unique insights and abilities that professional managers do not, primarily because they have a deep understanding of their company's vision and culture. --- Chunk_id: 1
# 3) Content: Unique Founder Abilities
# Founders possess unique insights and abilities that professional managers do not, primarily because they have a deep understanding of their company's vision and culture.
# Graham suggests that founders should leverage these strengths rather than conform to traditional managerial practices. "Founder Mode" is an emerging paradigm that is not yet fully understood or documented, with Graham hoping that over time, it will become as well-understood as the traditional manager mode, allowing founders to maintain their unique approach even as their companies scale.
# Challenges of Scaling Startups
# As startups grow, there is a common belief that they must transition to a more structured managerial approach. However, many founders have found this transition problematic, as it often leads to a loss of the innovative and agile spirit that drove the startup's initial success. --- Chunk_id: 2

# %% [markdown]
# #### Test - 3

# %%
test_query_3 = "when was the essay \"founder mode\" published?"
res_proposition = retriever_propositions.invoke(test_query_3)
res_larger = retriever_larger.invoke(test_query_3)
# Out:
# OllamaEmbeddings:   0%|          | 0/1 [00:00<?, ?it/s]
# OllamaEmbeddings: 100%|██████████| 1/1 [00:00<00:00, 16.67it/s]
# OllamaEmbeddings: 100%|██████████| 1/1 [00:00<00:00, 36.51it/s]

# %%
for i, r in enumerate(res_proposition):
    print(f"{i+1}) Content: {r.page_content} --- Chunk_id: {r.metadata['chunk_id']}")
# Out:
# 1) Content: Paul Graham published an essay called 'Founder Mode' in September 2024. --- Chunk_id: 1
# 2) Content: Founder Mode is an emerging paradigm. --- Chunk_id: 1
# 3) Content: Founder Mode is an emerging paradigm that is not yet fully understood or documented. --- Chunk_id: 2
# 4) Content: Paul Graham's essay 'Founder Mode' challenges conventional wisdom about scaling startups. --- Chunk_id: 1

# %%
for i, r in enumerate(res_larger):
    print(f"{i+1}) Content: {r.page_content} --- Chunk_id: {r.metadata['chunk_id']}")
# Out:
# 1) Content: Paul Graham's essay "Founder Mode," published in September 2024, challenges conventional wisdom about scaling startups, arguing that founders should maintain their unique management style rather than adopting traditional corporate practices as their companies grow.
# Conventional Wisdom vs. Founder Mode
# The essay argues that the traditional advice given to growing companies—hiring good people and giving them autonomy—often fails when applied to startups.
# This approach, suitable for established companies, can be detrimental to startups where the founder's vision and direct involvement are crucial. "Founder Mode" is presented as an emerging paradigm that is not yet fully understood or documented, contrasting with the conventional "manager mode" often advised by business schools and professional managers.
# Unique Founder Abilities
# Founders possess unique insights and abilities that professional managers do not, primarily because they have a deep understanding of their company's vision and culture. --- Chunk_id: 1
# 2) Content: Unique Founder Abilities
# Founders possess unique insights and abilities that professional managers do not, primarily because they have a deep understanding of their company's vision and culture.
# Graham suggests that founders should leverage these strengths rather than conform to traditional managerial practices. "Founder Mode" is an emerging paradigm that is not yet fully understood or documented, with Graham hoping that over time, it will become as well-understood as the traditional manager mode, allowing founders to maintain their unique approach even as their companies scale.
# Challenges of Scaling Startups
# As startups grow, there is a common belief that they must transition to a more structured managerial approach. However, many founders have found this transition problematic, as it often leads to a loss of the innovative and agile spirit that drove the startup's initial success. --- Chunk_id: 2
# 3) Content: Brian Chesky, co-founder of Airbnb, shared his experience of being advised to run the company in a traditional managerial style, which led to poor outcomes. He eventually found success by adopting a different approach, influenced by how Steve Jobs managed Apple.
# Steve Jobs' Management Style
# Steve Jobs' management approach at Apple served as inspiration for Brian Chesky's "Founder Mode" at Airbnb. One notable practice was Jobs' annual retreat for the 100 most important people at Apple, regardless of their position on the organizational chart
# . This unconventional method allowed Jobs to maintain a startup-like environment even as Apple grew, fostering innovation and direct communication across hierarchical levels. Such practices emphasize the importance of founders staying deeply involved in their companies' operations, challenging the traditional notion of delegating responsibilities to professional managers as companies scale. --- Chunk_id: 3

# %% [markdown]
# ### Comparison
#
# | **Aspect**                | **Proposition-Based Retrieval**                                         | **Simple Chunk Retrieval**                                              |
# |---------------------------|--------------------------------------------------------------------------|--------------------------------------------------------------------------|
# | **Precision in Response**  | High: Delivers focused and direct answers.                              | Medium: Provides more context but may include irrelevant information.    |
# | **Clarity and Brevity**    | High: Clear and concise, avoids unnecessary details.                    | Medium: More comprehensive but can be overwhelming.                      |
# | **Contextual Richness**    | Low: May lack context, focusing on specific propositions.               | High: Provides additional context and details.                           |
# | **Comprehensiveness**      | Low: May omit broader context or supplementary details.                 | High: Offers a more complete view with extensive information.            |
# | **Narrative Flow**         | Medium: Can be fragmented or disjointed.                                | High: Preserves the logical flow and coherence of the original document. |
# | **Information Overload**   | Low: Less likely to overwhelm with excess information.                  | High: Risk of overwhelming the user with too much information.           |
# | **Use Case Suitability**   | Best for quick, factual queries.                                        | Best for complex queries requiring in-depth understanding.               |
# | **Efficiency**             | High: Provides quick, targeted responses.                               | Medium: May require more effort to sift through additional content.      |
# | **Specificity**            | High: Precise and targeted responses.                                   | Medium: Answers may be less targeted due to inclusion of broader context.|
